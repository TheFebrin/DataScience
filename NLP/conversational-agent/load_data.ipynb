# %%
import pandas as pd
from tqdm import tqdm
from typing import *
import json

# %%
def process_line(line):
    processed_line: List[str] = line.replace('\n', '').strip().split('  ===>  ')
    assert len(processed_line) == 2
    return processed_line

# %%
data1 = []
with open('data/pseudo_dialogs_ver1.txt', 'r', encoding='utf8') as f:
    for x in f.readlines():
        data1.append(process_line(x))

# %%
import json
def process_line(line) -> Tuple[str, str]:
    data = json.loads(line)
    return data['queries']['pl'], data['answers']['pl'][0]['text']

# %%
data = []
with open('data/mkqa.jsonl', 'r', encoding='utf8') as f:
    for l in f.readlines():
        data.append(process_line(l))

# %%
with open('data/sitcoms/hilda3.txt', 'r', encoding='utf8') as f:
    text = f.readlines()
    text = list(map(lambda x: x.replace('-', '').strip(), text))
    text = list(filter(
        lambda x: len(x) > 1 and x.find('-->') == -1 and not x.isdigit() and x.find(' > ') == -1,
        text
    ))
    text = list(map(lambda x: x.replace('<i>', '').replace('</i>', '').strip(), text))
    for x in text:
        print(x)
# Out:
# NETFLIX — SERIAL ORYGINALNY
# ROZDZIAŁ 5: WIATRAK
# Zjesz coś przed wyjściem?
# Nie, wezmę jabłko.
# Jak tu czysto.
# Tontu schował rzeczy
# do Ukrytej przestrzeni.
# Szafki zrobiły się lżejsze.
# Spójrz, ile tu miejsca.
# Tontu, podasz mi szpatułkę?
# I miskę.
# Dziękuję.
# Proszę.
# Tontu.
# Zabierz mnie do Fridy. Będzie szybciej.
# Nie, nikogo już tam nie wpuszczę.
# Dlaczego?
# To miejsce dla krasnoludków.
# Ludzie nie powinni w nim przebywać.
# Mama zrobiła z niego spiżarnię.
# Tak, ale nie wchodzi.
# No i robi mi śniadanie.
# Obok nas istnieje sekretny świat,
# a on nie da mi zajrzeć.
# To nie fair.
# To tylko nicość.
# Żebyś to zobaczyła.
# A wasze krasnoludki?
# Jakie one są?
# Nie interesują mnie
# po problemach z książką.
# Ja ich nie mam.
# Na pewno masz, tylko się nie narzucają.
# Kiedyś ludzie przekazywali im dary,
# by opiekowały się domami.
# Dobra! Skupmy się na ptasiej odznace.
# Szukajcie szkarłatnego śpiewaka.
# Jest wart dziesięć punktów.
# Czemu to robią?
# By wybudować domy?
# Szkarłatny śpiewak!
# Odleciał! Chodźcie!
# Ale strasznie.
# Chodź, David!
# Biegnę!
# Witam. Przepraszamy za najście.
# Szliśmy za ptakiem…
# Znam ten głos.
# To wy!
# To pani!
# Kto?
# Victoria Van Gale.
# Szalona meteorolożka?
# To niezbyt…
# Przepraszam za okoliczności
# ostatniego spotkania.
# Praca nieco mnie poniosła.
# Łagodnie mówiąc.
# Ale teraz się zmieniłam.
# Jak mamy pani ufać?
# Nie możemy. Chodźmy.
# Pani Van Gale?
# Mówcie mi po imieniu.
# Victoria, mogę zrobić zdjęcie tych ptaków?
# Chcemy zdobyć odznakę.
# Oczywiście.
# Wejdźcie na chwilę.
# Ludzie rzadko tu wpadają.
# Dobrze. Może być miło.
# Przy okazji,
# na krokwi jest gniazdo
# cętkowanej jaskółki.
# Powinnaś zrobić jej zdjęcie.
# Zgadzam się.
# Mam złe przeczucia.
# Witajcie w moich skromnych progach.
# Mieszkasz tu?
# Ostatni dom się nieco posypał,
# jeśli rozumiecie.
# Teraz żyję poza cywilizacją.
# Tylko ja, las i trochę kompanów.
# Nie eksperymentujesz na nich, prawda?
# Na niebiosa. W życiu.
# Zabieram je z budowy przy drodze.
# Kiedy przenocujesz kilka wiewiórek,
# to zyskujesz renomę.
# Świetna kolekcja książek.
# Tylko je uratowałam
# z instytutu meteorologii.
# Smutne pozostałości ogromnej kolekcji.
# Co to?
# Nie wspomniałam, że teraz piekę.
# Skusicie się na ciastko?
# David, uwielbiasz ciastka.
# Proszę.
# Pójdę fotografować ptaki.
# Jak chcesz.
# Hej!
# Ale pyszne.
# Hilda, chodź na chwilę.
# Nie rozumiem. To drzwi.
# Do piwnicy.
# Prowadzą do piwnicy,
# a te nigdy nie są dobre.
# U nas są dziadki do orzechów taty.
# Naprawdę nic tu nie ma.
# Mówię ci, wbiegło tu coś dziwnego.
# Ja też nie ufam Victorii,
# ale może nie ma powodów do obaw.
# Jest nieco stuknięta, ale spójrz.
# Nic tu nie ukrywa.
# Może tak.
# Wariuję.
# Mówiłem ci!
# Dobra, gratulacje.
# Co to jest?
# Nie byłam pewna cynamonu,
# ale sprawdził się.
# Słyszysz?
# Co wy tam robiliście?
# No nie wiem,
# odkrywaliśmy sekretne laboratorium!
# Wiedziałem, że coś knujesz!
# Co ty pleciesz?
# To wariatka!
# Robi potwory w piwnicy! Spójrz!
# Wygląda jak Tontu, mój krasnoludek.
# Taki był plan.
# Krasnoludki są przydatne.
# Bardzo by mi się tu jakiś przydał.
# Zbudowałam go, by mi pomagał.
# Zbudowałaś? Jak?
# Czysta nauka.
# Chciał nas zjeść!
# Bywa zachłanny, wiem.
# Ale bardzo ułatwił mi życie.
# To dużo więcej niż mój krasnoludek.
# Nie wpuści mnie do Ukrytej przestrzeni.
# A więc widziałaś je?
# Kilka razy.
# Fascynujące.
# Widzicie, o czym mówię?
# Ten dom się rozpada.
# Nie nadążam z naprawą.
# No, leć po kit!
# Może my pomożemy?
# Zrobimy remont.
# Czemu mielibyśmy to zrobić?
# Bo zdobylibyśmy kilka odznak harcerza.
# Dbanie o zwierzęta,
# remont i projekt wnętrz.
# Ten dziwny krasnolud jej pomaga.
# Nie da rady zrobić wszystkiego.
# Przyznaję, że byłabym wam
# niezmiernie wdzięczna.
# Zbudowała krasnoludka sama
# z drewna i trawy.
# Zbudowała? A więc nie jest prawdziwy?
# Nie. A gdyby był,
# wziąłby mnie do Ukrytej przestrzeni.
# I robi to, o co go poprosi.
# Zdrzemnę się.
# Ukryta przestrzeń może być wszędzie.
# Pod szafą, między deskami,
# w rysie na ścianie.
# Naprawdę? To fascynujące.
# Ułożyłam już książki.
# Posortowałam je według tematu,
# ale też tak, by ładnie wyglądały.
# Jeszcze tylko dziura w ścianie.
# I gotowe.
# Nie!
# Dość już zrobiłyście.
# Odwdzięczę się wam.
# Głodni?
# Victoria, to przepyszne. Nie musiałaś.
# Bzdura, to nic takiego.
# Przynajmniej tak się mogę odwdzięczyć.
# Kawy?
# Nie, dzięki.
# David, powinieneś spróbować.
# Dobrze.
# Tak, jest pyszne.
# W kuchni jest więcej.
# Bądź tak miły i je przynieś.
# Nie, ja przyniosę.
# Victoria, wybacz mi.
# Wciąż uważam, że jesteś wariatką,
# ale nie niebezpieczną.
# Cóż, dziękuję.
# Mogę to naprawić.
# Co?
# Dobrze, że jesteś. Czas na prezenty.
# Prezenty?
# W ramach podziękowania
# chcę dać każdemu z was prezent.
# Frida, możesz wziąć dowolną książkę
# z mojej pięknie poukładanej biblioteki.
# Hilda, zauważyłam, jak bardzo polubiłaś
# moich małych przyjaciół.
# Proszę bardzo.
# Wiem, że dobrze się nimi zajmiesz.
# David.
# Co?
# David.
# Dla ciebie…
# to.
# Uniwersalny smar?
# Za twoją wszechstronność.
# Powinniście już iść do domu.
# Zaraz będzie burza.
# Skąd wiesz?
# Wiecie, co mówią,
# meteorologiem jest się na zawsze.
# Szybko, zanim zacznie padać.
# Było miło.
# Będzie padać, tak jak mówiła.
# Ma nosa do pogody.
# Muszę wam coś pokazać.
# O nie! Zapomniałam wybrać książkę!
# Frida!
# Do jutra.
# Lecę na drugi obiad.
# Muszę zdążyć.
# Hilda!
# Jutro pokażesz!
# Zdecydowałaś się już?
# Spory wybór.
# „Reanimacja. Ogólny poradnik”.
# Sporo książek o czarnej magii
# jak na ścisły umysł.
# To dobre książki.
# Odskocznia od rygoru nauki.
# Magia też potrafi być rygorystyczna.
# Trafna uwaga.
# Gdzie się podział mój asystent?
# Co kombinujesz, Victoria?
# To plan.
# Jakiejś tajemnej maszyny?
# Wiatrak jest tą maszyną.
# Ty!
# Wszystko gra, David?
# Tak, turlałem się. Chyba znowu wyjdę…
# Nie ma mowy.
# Dziś kąpiel.
# Dobra. To zostanę w pokoju.
# Okno!
# Nie, nie zrobię tego.
# Muszę to jak najszybciej pokazać Hildzie.
# Ale jak, skoro nie mogę wyjść?
# Jeśli jesteś tu, krasnoludzie,
# oto moje dary dla ciebie.
# Musimy pogadać.
# Kurka!
# SMAR
# To smar uniwersalny?
# Z początku byłam nieufna, ale Van Gale…
# Hilda!
# David!
# Jak to? Nie rozumiem.
# Dzięki!
# Muszę ci coś pokazać.
# Wiatrak jest tajemną maszyną?
# A jej stwór jest z tym związany.
# Jest jeszcze gorzej.
# O co chodzi?
# To stara magia. Bardzo stara.
# Taka, z którą lepiej nie igrać.
# Krasnolud nie jest zbudowany,
# a zaklęty!
# Tyle zachodu dla krasnoludka? Bez urazy.
# Nie szkodzi.
# Chce trafić do Ukrytej przestrzeni.
# Nie może tego użyć.
# Lećmy szybko.
# Chodźmy też po Fridę.
# Nie ma czasu.
# Musimy jak najszybciej tam dotrzeć.
# A więc…
# Tylko ten jeden raz, jasne?
# Dziękuję.
# Już czas.
# W końcu wybrałam książkę.
# „Uciekaj stąd. Ocena ryzyka
# i nauka wychodzenia w porę”.
# David miał rację. Wariatka!
# To nie tak. Nie obrażaj się.
# Po prostu próbowałabyś mnie powstrzymać.
# Stworzymy dziś kawał historii.
# Co się dzieje?
# Wpadłam na to
# dzięki tej budowie przy drodze.
# W Trolbergu nie ma już miejsca,
# ale w Nicomiejscu jest go mnóstwo.
# Można budować domy tam,
# zamiast niszczyć ostatki lasu!
# Po co krasnoludkom tyle pięknej,
# bezkresnej przestrzeni?
# Za późno!
# David! Hilda!
# Frida! Wciąż tu jesteś?
# Ma świetne książki. Nie mogłam wybrać.
# Gdzie ona jest?
# W środku!
# Co, jeśli tego nie zatrzymamy?
# Tak długa wyrwa?
# Może wchłonąć całe miasto
# w tę bezkresną nicość.
# Mogłam nie pytać.
# Victoria!
# Hilda! Cieszę się, że tu jesteś.
# Wyłącz to natychmiast.
# Czemu? Jestem bliska
# stworzenia czegoś wspaniałego.
# Czegoś dobrego dla świata.
# Ściskasz mnie!
# Wybacz!
# Uważaj!
# Wiem, że popełniłam błędy,
# ale dzięki temu je naprawię!
# Nic się nie zmieniłaś.
# Hilda, spójrz, co zrobiłam!
# Też chciałaś odkrywać to miejsce.
# Nie w ten sposób. To nie twój świat.
# A jednak tu jestem.
# Zaczyna się.
# Nie rozumiem. Obliczyłam wszystko.
# Moja maszyna.
# Victoria, uciekajmy!
# Uciekaj!
# Gdzie Hilda?
# Stracimy szansę!
# Proszę!
# Idźcie!
# Victoria, nie!
# Hilda!
# Jesteśmy ci winne przeprosiny.
# Nie trzeba, wierzycie w ludzi.
# To dobra cecha.
# Najczęściej.
# Sądziłam, że się zmieniła.
# Jest wasz.
# Napisy: Krzysztof Zając

# %%
len(text)
# Out:
# 572

# %%
list(zip(tmp, text[:10]))
# Out:
# [('abc', 'CHCIAŁBYM MIEĆ'),
#  ('CHCIAŁBYM MIEĆ', 'PÓŁTORAMETROWĄ KUTANGĘ'),
#  ('PÓŁTORAMETROWĄ KUTANGĘ', 'ZAKŁAD KARNY SUNNYVALE'),
#  ('ZAKŁAD KARNY SUNNYVALE', 'PRZEDMIEŚCIA DARTMOUTH, NOWA SZKOCJA'),
#  ('PRZEDMIEŚCIA DARTMOUTH, NOWA SZKOCJA', 'BIURO SZERYFA'),
#  ('BIURO SZERYFA', 'Ja pierdolę.'),
#  ('Ja pierdolę.', 'W usta to ja cię wypierdolę.'),
#  ('W usta to ja cię wypierdolę.', 'Witamy z powrotem, chłopcy.'),
#  ('Witamy z powrotem, chłopcy.', 'Jeb się na ryj, Josh.'),
#  ('Jeb się na ryj, Josh.', 'Możesz mi naskoczyć.')]

# %% [markdown]
# ## Load PolBert

# %%
# !pip install transformers -q
# Out:
# WARNING: You are using pip version 21.0.1; however, version 22.3 is available.
# You should consider upgrading via the 'c:\users\febrin\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.

# %%
# !pip -V
# Out:
# pip 21.0.1 from c:\users\febrin\appdata\local\programs\python\python37\lib\site-packages\pip (python 3.7)

# %%
from transformers import *
# Out:
# -----------------------------------------------------------
# ModuleNotFoundError       Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\transformers\utils\import_utils.py in _get_module(self, module_name)
#    1062         try:
# -> 1063             return importlib.import_module("." + module_name, self.__name__)
#    1064         except Exception as e:
#
# ~\AppData\Local\Programs\Python\Python37\lib\importlib\__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# ~\AppData\Local\Programs\Python\Python37\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# ~\AppData\Local\Programs\Python\Python37\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\AppData\Local\Programs\Python\Python37\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~\AppData\Local\Programs\Python\Python37\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# ~\AppData\Local\Programs\Python\Python37\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# ~\AppData\Local\Programs\Python\Python37\lib\importlib\_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\transformers\models\decision_transformer\modeling_decision_transformer.py in <module>
#      24 from torch import nn
# ---> 25 from torch.cuda.amp import autocast
#      26
#
# ModuleNotFoundError: No module named 'torch.cuda.amp'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError              Traceback (most recent call last)
# <ipython-input-16-84c1aa520d59> in <module>
# ----> 1 from transformers import *
#
# ~\AppData\Local\Programs\Python\Python37\lib\importlib\_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# ~\AppData\Local\Programs\Python\Python37\lib\importlib\_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\transformers\utils\import_utils.py in __getattr__(self, name)
#    1052         elif name in self._class_to_module.keys():
#    1053             module = self._get_module(self._class_to_module[name])
# -> 1054             value = getattr(module, name)
#    1055         else:
#    1056             raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\transformers\utils\import_utils.py in __getattr__(self, name)
#    1051             value = self._get_module(name)
#    1052         elif name in self._class_to_module.keys():
# -> 1053             module = self._get_module(self._class_to_module[name])
#    1054             value = getattr(module, name)
#    1055         else:
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\transformers\utils\import_utils.py in _get_module(self, module_name)
#    1066                 f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1067                 f" traceback):\n{e}"
# -> 1068             ) from e
#    1069
#    1070     def __reduce__(self):
#
# RuntimeError: Failed to import transformers.models.decision_transformer.modeling_decision_transformer because of the following error (look up to see its traceback):
# No module named 'torch.cuda.amp'
