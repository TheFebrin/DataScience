# %%
import numpy as np
import pandas as pd
import openai
from tqdm import tqdm
import json

from typing import *
from gpt_api import GPT3API

# %% [markdown]
# ## Explore questions and answers

# %%
questions, answers = [], []
with open('data/task2_questions_with_answers.tsv', encoding="UTF-8") as f:
    for line in f.readlines():
        try:
            q, *a = line.strip().split('\t')
            questions.append(q)
            answers.append(a)
        except Exception as e:
            print(line)

# %%
subset_q = [q for i,q in enumerate(questions) if i % 5 == 0]
subset_a = [a for i,a in enumerate(answers) if i % 5 == 0]

# %%
longest_answer = 30
for i, ans in enumerate(answers):
    for a in ans:
        if len(a) > longest_answer:
            longest_answer = len(a)
            print(questions[i])
            print(ans)
            print('---')
# Out:
# Wyspy Zielonego Przylądka leżą bliżej Afryki czy Azji?
# ['Kto śpiewa piosenkę z czołówki M jak miłość?']
# ---
# Proszę rozszyfrować skrót KBWE?
# ['Konferencja Bezpieczeństwa i Współpracy w Europie']
# ---
# Dybuk to dusza zmarłego grzesznika wstępująca do ciała żywego czy duch w domostwie domowym?
# ['dusza zmarłego grzesznika wstępująca do ciała żywego']
# ---
# Jakie dwie prace Heraklesa były związane z końmi?
# ['posprzątanie stajni Augiasza i schwytanie koni Diomedesa', 'schwytanie koni Diomedesa i posprzątanie stajni Augiasza']
# ---

# %% [markdown]
# ## GPT fine tuning ideas:
# 1. limit number of tokens
# 2. self-ask https://the-decoder.com/new-prompt-method-lets-gpt-3-answer-questions-better/
# 3. rules for "or" type questions
# 4. use A to finetune GPT

# %% [markdown]
# Direct prompt:
# ```
# Question: Who was president of the U.S. when superconductivity was discovered?
#
# Answer: The president of the United States when superconductivity was discovered was Dwight D. Eisenhower. Superconductivity was discovered in 1911 by Dutch physicist Heike Kamerlingh Onnes.
# ```
#
# Self-ask prompt:
#
# ```
# Question: Who lived longer, Theodor Haecker or Harry Vaughan Watkins?
# Are follow up questions needed here: Yes.
# Follow up: How old was Theodor Haecker when he died?
# Intermediate answer: Theodor Haecker was 65 years old when he died.
# Follow up: How old was Harry Vaughan Watkins when he died?
# Intermediate answer: Harry Vaughan Watkins was 69 years old when he died.
# So the final answer is: Harry Vaughan Watkins
#
# Question: Who was president of the U.S. when superconductivity was discovered?
# Are follow up questions needed here: Yes.
# Follow up: When was superconductivity discovered?
# Intermediate answer: Superconductivity was discovered in 1911.
# Follow up: Who was president of the U.S. in 1911?
# Intermediate answer: William Howard Taft was president of the U.S. in 1911.
# So the final answer is: William Howard Taft.
# ```

# %% [markdown]
# ## Utils

# %%
follow_up_questions = [
    "Kto żył dłużej, Theodor Haecker czy Harry Vaughan Watkins?",
    "W jakim wieku był Theodor Haecker gdy zmarł?",
    "W jakim wieku Harry Vaughan Watkins był gdy zmarł?",
]

follow_up_answers = [
    "Harry Vaughan Watkins",
    "Theodor Haecker miał 65 lat gdy zmarł.",
    "Harry Vaughan Watkins miał 69 lat gdy zmarł.",
]

follow_up_answers_short = [
    "Harry Vaughan Watkins",
    "65",
    "69",
]

# %%
def prepare_self_ask(
    question: str, 
    follow_up_questions: List[str], 
    follow_up_answers: List[str]
) -> str:
    return (
        f"Pytanie: {follow_up_questions[0]}\n"
        "Czy potrzebne są tutaj pomocnicze pytania: Tak\n"
        f"Pomocnicze pytanie: {follow_up_questions[1]}\n"
        f"Pomocnicza odpowiedź: {follow_up_answers[1]}\n"
        f"Pomocnicze pytanie: {follow_up_questions[2]}\n"
        f"Pomocnicza odpowiedź: {follow_up_answers[2]}\n"
        f"Ostateczna odpowiedź: {follow_up_answers[0]}\n\n"
        f"Pytanie: {question} Odpowiedz krótko.\n"
        f"Czy potrzebne są tutaj pomocnicze pytania: Tak."
    )


def is_or_question() -> bool:
    ...

def handle_or_question() -> str:
    ...

# %%
api = GPT3API()
openai.api_key = "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"

# %%
prepared_question = prepare_self_ask(
    question="Kto jest autorem obrazu namalowanego w 1892 r. Kobiety z Tahiti?",
    follow_up_questions=follow_up_questions,
    follow_up_answers=follow_up_answers,
)
print(prepared_question)

response = api.send_prompt(
    prompt=prepared_question,
    temperature=0,
    max_length_tokens=256,
)
print(response)
# Out:
# Pytanie: Kto żył dłużej, Theodor Haecker czy Harry Vaughan Watkins?
# Czy potrzebne są tutaj pomocnicze pytania: Tak
# Pomocnicze pytanie: W jakim wieku był Theodor Haecker gdy zmarł?
# Pomocnicza odpowiedź: Theodor Haecker miał 65 lat gdy zmarł.
# Pomocnicze pytanie: W jakim wieku Harry Vaughan Watkins był gdy zmarł?
# Pomocnicza odpowiedź: Harry Vaughan Watkins miał 69 lat gdy zmarł.
# Ostateczna odpowiedź: Harry Vaughan Watkins
#
# Pytanie: Kto jest autorem obrazu namalowanego w 1892 r. Kobiety z Tahiti? Odpowiedz krótko.
# Czy potrzebne są tutaj pomocnicze pytania: Tak.
#
# Pomocnicze pytanie: Kto jest autorem obrazu Kobiety z Tahiti?
# Pomocnicza odpowiedź: Paul Gauguin jest autorem obrazu Kobiety z Tahiti.
# Ostateczna odpowiedź: Paul Gauguin.

# %%
# %%time
prepared_question_2 = prepare_self_ask(
    question="Ktoś „nie w ciemię bity” to ktoś sprytny czy naiwny?",
    follow_up_questions=follow_up_questions,
    follow_up_answers=follow_up_answers,
)
print(prepared_question_2)

response = api.send_prompt(
    prompt=prepared_question_2,
    temperature=0,
    max_length_tokens=256,
)
print(response)
# Out:
# Pytanie: Kto żył dłużej, Theodor Haecker czy Harry Vaughan Watkins?
# Czy potrzebne są tutaj pomocnicze pytania: Tak
# Pomocnicze pytanie: W jakim wieku był Theodor Haecker gdy zmarł?
# Pomocnicza odpowiedź: Theodor Haecker miał 65 lat gdy zmarł.
# Pomocnicze pytanie: W jakim wieku Harry Vaughan Watkins był gdy zmarł?
# Pomocnicza odpowiedź: Harry Vaughan Watkins miał 69 lat gdy zmarł.
# Ostateczna odpowiedź: Harry Vaughan Watkins
#
# Pytanie: Ktoś „nie w ciemię bity” to ktoś sprytny czy naiwny? Odpowiedz krótko.
# Czy potrzebne są tutaj pomocnicze pytania: Tak
#
# Pomocnicze pytanie: Co oznacza powiedzenie „nie w ciemię bity”?
# Pomocnicza odpowiedź: Powiedzenie „nie w ciemię bity” oznacza, że ktoś jest sprytny i zdolny do wyciągania wniosków.
# Ostateczna odpowiedź: Sprytny.
# CPU times: total: 15.6 ms
# Wall time: 4.55 s

# %% [markdown]
# ## Dataset A

# %% [markdown]
# ### Answers from GPT

# %%
from concurrent.futures import ThreadPoolExecutor
from threading import Lock

gpt_answers = {}
gpt_answers_lock = Lock()

# %%
def get_gpt_answer(question: str) -> None:
        prompt = prepare_self_ask(
            question=question.strip(),
            follow_up_questions=follow_up_questions,
            follow_up_answers=follow_up_answers,
        )
        answer = api.send_prompt(
            prompt=prompt,
            temperature=0,
            max_length_tokens=256,
        )
        with gpt_answers_lock:
            gpt_answers[question] = answer


with ThreadPoolExecutor(max_workers=3) as pool:
    futures = []
    for q in tqdm(questions):
        future = pool.submit(get_gpt_answer, q)
        futures.append(future)

    for fut in futures:
        fut.result()
# Out:
# 100%|██████████| 3500/3500 [00:00<00:00, 69928.71it/s]

# %%
# gpt_answers

# %% [markdown]
# ## Dataset B

# %%
questions_b, answers_b = [], []
with open('data/B.answers', encoding="UTF-8") as f:
    for line in f.readlines():
        try:
            a = line.strip()
            answers_b.append(a)
        except Exception as e:
            print(line)

with open('data/B.questions', encoding="UTF-8") as f:
    for line in f.readlines():
        try:
            q = line.strip()
            questions_b.append(q)
        except Exception as e:
            print(line)

# %% [markdown]
# ## Answers for dataset B

# %%
gpt_answers = {}
gpt_answers_exceptions = []

# %%
def get_gpt_answer(question: str) -> None:
        prompt = prepare_self_ask(
            question=question.strip(),
            follow_up_questions=follow_up_questions,
            follow_up_answers=follow_up_answers,
        )
        answer = api.send_prompt(
            prompt=prompt,
            temperature=0,
            max_length_tokens=256,
        )
        gpt_answers[question] = answer



for q in tqdm(questions_b):
    try:
        answer = get_gpt_answer(q)
    except Exception as e:
        gpt_answers_exceptions.append(q)
# Out:
# 100%|██████████| 2500/2500 [2:48:52<00:00,  4.05s/it]

# %%
gpt_answers_exceptions
# Out:
# ['Jak nazywa się gazeta, którą można czytać na ekranie telewizora?',
#  'Któremu twórcy poświęcona jest krakowska instytucja kultury Cricoteka?',
#  'Jak nazywa się stolica Korei Południowej?',
#  'Jak nazywa się instrument Murzynów amerykańskich, chordofon szarpany z okrągłym pudłem rezonansowym krytym błoną z długą szyjką i 4–9 strunami?']

# %%
def get_gpt_answer(question: str) -> None:
        prompt = prepare_self_ask(
            question=question.strip(),
            follow_up_questions=follow_up_questions,
            follow_up_answers=follow_up_answers,
        )
        answer = api.send_prompt(
            prompt=prompt,
            temperature=0,
            max_length_tokens=256,
        )
        gpt_answers[question] = answer



for q in tqdm(gpt_answers_exceptions):
    #try:
    answer = get_gpt_answer(q)
    #except Exception as e:
    #    gpt_answers_exceptions.append(q)
# Out:
# 100%|██████████| 4/4 [00:14<00:00,  3.60s/it]

# %%
with open('BData/all_answers.txt', 'w') as file:
    file.write(json.dumps(gpt_answers))

# %%
with open('BData/all_answers.txt') as f:
    data = f.read()
    saved_answers = json.loads(data)

# %%
for q in questions_b:
    with open("BData/found_answers.txt", 'a') as f:
        a = gpt_answers[q][gpt_answers[q].find("Ostateczna odpowiedź:") + len("Ostateczna odpowiedź:"):]
        f.write(a.strip() + '\n')

# %%
for q in questions_b:
     a = gpt_answers[q][gpt_answers[q].rfind("Ostateczna odpowiedź:") + len("Ostateczna odpowiedź:"):]
     if "Ostateczna odpowiedź:" not in gpt_answers[q]:
           a = gpt_answers[q][gpt_answers[q].rfind("Pomocnicza odpowiedź:") + len("Pomocnicza odpowiedź:"):]
     if "Pomocniczna" in a or "Pomocnicze" in a:
          print(q)
          #print(gpt_answers[q])
          print(a)
          a = ""
     
     a = a.replace(".", '')
     with open("testing/found_answers.txt", 'a') as f:
          f.write(a.strip() + '\n')
# Out:
# Która figura geometryczna może być pitagorejska, ostrokątna, indyjska, egipska?
#  Figura indyjska to trójkąt, w którym jeden z boków jest dłuższy od pozostałych dwóch.
# Pomocnicze pytanie: Co to

# %%
def format_gpt_answer(long_gpt_answer: str) -> str:
    return long_gpt_answer.split('\n')[-1].replace("Ostateczna odpowiedź: ", '').strip('.').lower()

# %%
correct_geographical_location = {
    "chiny": "w chinach",
    "egipt": "w egipcie",
    "azja": "w azji",
    "afryka": "w afryce",
    "indie": "w indiach",
    "kraków": "w krakowie"
}

extract_number ={
    "jeden": 1,
    "raz": 1,
    "dwa": 2,
    "trzy": 3,
    "cztery": 4,
    "pięć": 5,
    "sześć": 6,
    "siedem": 7,
    "osiem": 8,
    "dziewięć": 9,
    "dziesięć": 10,
}

# %%
def modify_gpt_answer(gpt_ans: str) -> str:
    if len(gpt_ans) > 3 and gpt_ans[:3] in  ("tak", "nie"):
        gpt_ans = gpt_ans[:3]
    if gpt_ans[0].isdigit():
        gpt_ans = "".join(list(filter( lambda x: x.isdigit() or x in ('-'), gpt_ans)))
    if gpt_ans in correct_geographical_location:
        gpt_ans = correct_geographical_location[gpt_ans]
    if gpt_ans.split()[0] in extract_number:
        gpt_ans = str(extract_number[gpt_ans.split()[0]])

    if len(list(filter( lambda x: x.isdigit() or x in ('-'), gpt_ans))) > 0:
        gpt_ans = "".join(list(filter( lambda x: x.isdigit() or x in ('-'), gpt_ans)))

    if len(gpt_ans.split(",")) > 0:
        gpt_ans = gpt_ans.split(",")[0]
    
    return gpt_ans

# %%
with open("BData/found_answers.txt", 'w') as f:
    for q in questions_b:
        if "Ostateczna odpowiedź:" not in saved_answers[q]:
           a = saved_answers[q][saved_answers[q].rfind("Pomocnicza odpowiedź:") + len("Pomocnicza odpowiedź:"):]
        else:
            a = format_gpt_answer(saved_answers[q])

        if "Pomocniczna" in a or "Pomocnicze" in a:
            #print(q)
        #   #print(gpt_answers[q])
            print(a)
            a = "a"
        
        a = modify_gpt_answer(a)
        a = a.replace(".", '')
        
        f.write(a.strip() + '\n')
# Out:
#  Figura indyjska to trójkąt, w którym jeden z boków jest dłuższy od pozostałych dwóch.
# Pomocnicze pytanie: Co to

# %%
found_answers = []
correct_answers = []

for x in open('BData/correct_answers.txt', "r", encoding="utf-8"):
    x = x.strip()
    correct_answers.append(x.lower().split('\t'))
    
for x in open('BData/found_answers.txt', "r", encoding="utf-8"):    
    x = x.strip()
    found_answers.append(x.lower())

# %%
import editdistance
rn = ['ii', 'iii', 'iv', 'v', 'vi', 'vii', 'viii', 'ix', 'x', 'xi', 'xii', 'xiii',
                 'xiv', 'xv', 'xvi', 'xvii', 'xviii', 'xix', 'xx', 'xxi', 'xxii']

rome_numbers = dict(zip(rn, range(2, 23)))

def numbers_from(s):
    res = set()
    for w in s.split():
        w = w.lower()
        if w.isdecimal():
            res.add(w)
        if w in rome_numbers:
            res.add(rome_numbers[w])
    return res                 
                 
                 
def is_number(s):
    return lower(s) in rome_numbers or s.isdecimal()
                     
def scaled_editdist(ans, cor):
    ans = ans.lower()
    cor = cor.lower()
    
    return editdistance.eval(ans, cor) / len(cor)

def single_match(a, c):
    numbers_c = numbers_from(c)
    numbers_a = numbers_from(a)
        
    return numbers_a == numbers_c and scaled_editdist(a, c) < 0.5
        
def match(ans, cor):
    return any(single_match(ans, c) for c in cor)

for ans, cor in zip(found_answers, correct_answers):    
    if match(ans, cor):
        pass#score += 1
    else:
        print("WA: ", ans, cor)
# Out:
# WA:  europejska wspólnota węgla i stali powstała wcześniej ['europejska wspólnota węgla i stali']
# WA:  500 ['w xvi', '16']
# WA:  lada niva ['niva']
# WA:  godzilla ['king kong']
# WA:  powieść o aramisie napisał alexandre dumas ['„trzej muszkieterowie”']
# WA:  lina cumownicza ['cuma']
# WA:  zenon jazownik ['lucjan trela']
# WA:  akcja „krzyżaków” toczy się w xv wieku ['w xv', '15']
# WA:  cyrenejczyk i łazarz ['szymon cyrenejczyk', 'szymon z cyreny']
# WA:  olga tokarczuk ['wiesław myśliwski']
# WA:  instrument dęty blaszany ['dęty blaszany']
# WA:  brazylia ['przez peru', 'peru']
# WA:  hadley wynalazł równoleżnik ['sekstant']
# WA:  kabaret starszych panów ['kabaret tey', 'tey']
# WA:  w chinach ['chiny']
# WA:  obywatelem danii ['danii']
# WA:  nie ['tak']
# WA:  sejm ['zgromadzenie narodowe']
# WA:  - ['w saint tropez']
# WA:  łódź żaglowa na lodzie ['bojer']
# WA:  geologia strukturalna ['tektonika']
# WA:  krzyżacy ['przeciwko państwu krzyżackiemu', 'przeciw krzyżakom', 'państwo krzyżackie']
# WA:  gerlachovský štít ['gerlach']
# WA:  telewizyjna gazeta ['telegazeta']
# WA:  nadmiernej liczby palców ['palców']
# WA:  miliard milionów ['z miliona']
# WA:  alkaloid atropina ['atropina']
# WA:  owce moher ['z kóz']
# WA:  prozą ['wierszem']
# WA:  podgrzybki ['muchomory']
# WA:  torf leczniczy ['borowina']
# WA:  przywłaszczenie ['paserstwo']
# WA:  zagony tatarskie ['czambuły']
# WA:  tylne koło jest większe ['przednie']
# WA:  40 ['40 km/h']
# WA:  siła trzęsień ziemi ['trzęsienia ziemi']
# WA:  szabla jest najcięższą bronią używaną w szermierce sportowej ['szpada']
# WA:  - ['generał franciszek kleeberg', 'kleeberg']
# WA:  jezioro bodeńskie leży na granicy trzech państw europejskich: niemiec ['trzech', '3']
# WA:  tak ['nie']
# WA:  falkon jest bronią białą ['palną']
# WA:  ajschylos i eshil ['ajschylos']
# WA:  nil ['nad nilem']
# WA:  bolesław bierut ['edward gierek']
# WA:  jedno słowo ['jeden', '1']
# WA:  przewaga drzew iglastych ['iglastych']
# WA:  lipa ['dzięcielina']
# WA:  - ['renata mauer-różańska', 'mauer']
# WA:  - ['w województwie kujawsko-pomorskim', 'w kujawsko-pomorskim']
# WA:  skoki narciarskie ['bieg na 100 m przez płotki', '100 m ppł']
# WA:  urządzenie do głosowania ['urna']
# WA:  puszczę białą zamieszkują ludy kaszubów i kociewiaków ['kurpie']
# WA:  lamy należą do rodziny kóz ['wielbłądowatych']
# WA:  90 ['w v p.n.e.']
# WA:  nie ['białym']
# WA:  fobia pyrofobiczna ['arsonfobia']
# WA:  1970- ['siedemdziesiątych']
# WA:  order matrosova ['stachanowiec']
# WA:  odra ['pilica']
# WA:  liściaste ['iglaste']
# WA:  urugwaj był mistrzem świata w piłce nożnej dwa razy ['dwa', '2']
# WA:  epilog jest zakończeniem utworu ['zakończeniem']
# WA:  powieść władysława reymonta „chłopi” składa się z czterech tomów ['z czterech', '4']
# WA:  drużyna i kwiczoł ['batalion']
# WA:  28 ['w xviii', '18']
# WA:  1993 ['w xxi', '21']
# WA:  toulon ['w tulonie']
# WA:  1941 ['w 1943']
# WA:  20 ['warszawski indeks giełdowy', 'wig']
# WA:  dynastia burbonów ['z burbonów']
# WA:  1861 ['w xix', '19']
# WA:  władimir żarikow ['jacek wszoła']
# WA:  tak ['nie']
# WA:  drzewie ['na wierzbie']
# WA:  niska skala ['wysokiej']
# WA:  182830 ['był premierem', 'premiera']
# WA:  lizbona ['rzym']
# WA:  john gay ['ignacy krasicki', 'krasicki']
# WA:  szymon był rybakiem ['rybołóstwem']
# WA:  amfibia ['jaszcz']
# WA:  złącze ['elektroda']
# WA:  bismillah ['„sezamie, otwórz się”']
# WA:  jan kiliński ['maksymilian kolbe']
# WA:  tak ['na uczelniach wyższych']
# WA:  doba na marsie trwa krócej ['dłużej', 'dłużej niż ziemska']
# WA:  59 ['w xviii', '18']
# WA:  pierwiastek trzeciego stopnia z ośmiu wynosi dwa ['dwa', '2']
# WA:  auksyny to hormony wzrostowe roślin ['roślin']
# WA:  stanisław august poniatowski ['jan ii kazimierz waza']
# WA:  muchy ['mrówki']
# WA:  baht tajski ['baht']
# WA:  edyta bartosiewicz ['sława przybylska']
# WA:  aluminium ['glinu']
# WA:  maleństwo ['kangurzątko', 'kangur']
# WA:  we włoszech ['we francji']
# WA:  3 ['dwa', '2']
# WA:  na zachodzie bez zmian opowiada o losach siedmiu towarzyszy ['trzech', '3']
# WA:  lop oznacza logiczne programowanie obwodów ['liga ochrony przyrody']
# WA:  św piotr ['piotr']
# WA:  sole azotanowe i sole azotynowe ['azotany']
# WA:  hiszpańska ['francuskiej']
# WA:  skoki narciarskie ['w zapasach']
# WA:  car aleksander ii zniósł poddaństwo chłopów w rosji ['aleksander ii romanow']
# WA:  bolesław prus ['józef kraszewski']
# WA:  tyszkiewicz ['hanka ordonówna']
# WA:  stanisław august poniatowski ['zygmunt ii august']
# WA:  beskid wyspowy ['w tatrach', 'tatry']
# WA:  jan długosz ['paweł jasienica']
# WA:  nie ['tak']
# WA:  nie ['tak']
# WA:  kotwica ['orła']
# WA:  słowacja ['słowacji i ukrainy', 'ukrainy i słowacji']
# WA:  christiaan barnard dokonał pierwszej na świecie udanej przeszczepu serca ['transplantacji serca', 'przeszczepu serca']
# WA:  miedź cynkowa ['tombak']
# WA:  starożytna grecja ['po grecku']
# WA:  florencja ['w krakowie']
# WA:  tak ['nie']
# WA:  8 ['dziesięć', '10']
# WA:  2 ['cricot 2']
# WA:  baktrian ma więcej garbów ['baktrian']
# WA:  burbonowie ['z burbonów']
# WA:  112001 ['11 września 2001', '11.09.2001']
# WA:  tak ['dwa różne państwa']
# WA:  monachium ['wiedeń']
# WA:  strój sądowy ['toga']
# WA:  łódź katamaran ['katamaran']
# WA:  mięczaki ['graptolity']
# WA:  1 ['milion', '1000000']
# WA:  „pure nonsense” oznacza całkowity bezsens ['czysty nonsens']
# WA:  hispaniola ['na haiti']
# WA:  katedra św jana chrzciciela w warszawie ['w katedrze wawelskiej', 'na wawelu', '0']
# WA:  ameryka północna ['w azji', 'azja']
# WA:  antarktyda ['australia']
# WA:  struś południowoamerykański ['nandu']
# WA:  ofiara lub gambit ['gambit']
# WA:  koniczyna ['oset']
# WA:  interregnum ['vacatio legis']
# WA:  16 ['w xx', '20']
# WA:  antropologia ['etnografia']
# WA:  zakon jezuitów ['jezuici', 'towarzystwo jezusowe']
# WA:  próbujemy osiągnąć coś niemożliwego ['z motyką']
# WA:  do niewoli japończyków ['do japońskiej']
# WA:  1825 ['w grudniu']
# WA:  stara karta ['menora', 'siedmioramienny świecznik']
# WA:  francja ['hiszpanii i francji', 'francji i hiszpanii']
# WA:  wątroba składa się z czterech płatów ['z czterech', '4']
# WA:  wykres funkcji tangens nazywa się wykresem tangensa ['tangensoida']
# WA:  pieśni nabożne ['negro spirituals']
# WA:  beveridge'a ['kuroniówka']
# WA:  bibuła ['krepina']
# WA:  rejent milczek ['dyndalski']
# WA:  72 ['w xix', '19']
# WA:  powiedzenie „primum non nocere” oznacza „po pierwsze ['po pierwsze nie szkodzić']
# WA:  ropa naftowa musi być poddana procesowi rafinacji ['rektyfikacji']
# WA:  nie ['tak']
# WA:  "kobieta samotna" ['„moralność pani dulskiej”']
# WA:  intarsja wykorzystuje materiały naturalne ['z drewna']
# WA:  aktor ['protagonista']
# WA:  - ['kankan']
# WA:  trzech zawodników ['trzech', '3']
# WA:  320 ['z trzech', '3']
# WA:  nie ['sześć', '6']
# WA:  choroba hemofilii ['hemofilia']
# WA:  zielony ['czerwonego']
# WA:  ludzkimi ofiarami ['ludźmi']
# WA:  mauzoleum św piotra ['panteon narodowy']
# WA:  życiorys ubezpieczeniowy ['polisa']
# WA:  przekroczenie siatki ['net']
# WA:  duszpasterz wojskowy ['kapelan']
# WA:  tak ['nie']
# WA:  kokos ['jasiek']
# WA:  jezioro łańskie ['do odry']
# WA:  w wiśle ['z wisły']
# WA:  fale radiowe ['radiowe']
# WA:  sokrates umarł za pośrednictwem trucizny ['wypił cykutę', 'popełnił samobójstwo']
# WA:  edward miszczak ['stefan bratkowski']
# WA:  ocean indyjski jest najmniejszy ['ocean indyjski', 'indyjski']
# WA:  staroangielski ['z niemieckiego']
# WA:  trąbka ['na trąbce']
# WA:  reprezentacja zsrr ['z węgrami', 'węgry']
# WA:  pies ['był kotem']
# WA:  100 ['dwieście dwanaście', '212']
# WA:  zasady interpunkcji ['interpunkcja']
# WA:  holandia ['hiszpania']
# WA:  czubatka to polska rasa kur ['polska rasa kur', 'kur']
# WA:  polskie centrum badań kosmicznych ['„sonda”']
# WA:  argentyna i holandia ['holandia']
# WA:  rzymskie wodociągi ['akwedukty']
# WA:  orzeczenie imienne składa się z wyroku sądu ['z łącznika i orzecznika', 'z orzecznika i łącznika']
# WA:  wiek ['epoka']
# WA:  sofokles ['ajschylos']
# WA:  wielokropek składa się z wielu kropek ['trzy', '3']
# WA:  na zamówienie władz egipskich ['otwarcia kanału sueskiego']
# WA:  tak ['nie']
# WA:  pracownia sztuki ['atelier']
# WA:  "witness to power: the nixon years" ['„waszyngton za zamkniętymi drzwiami”']
# WA:  organista ['kalikant']
# WA:  słoń ['cielę', 'wół']
# WA:  obcokrajowców ['białych turystów', 'cudzoziemców', 'białych']
# WA:  skrzypce ['na wiolonczeli']
# WA:  w wieku vi ['w vi']
# WA:  prz ['przymiotnik']
# WA:  wojciech dąbrowski ['czesław nowicki']
# WA:  -2 ['mig-17']
# WA:  rafał szukiel ['mateusz kusznierewicz']
# WA:  żywny ['śniadeccy', 'śniadecki']
# WA:  płacić za zboże to płacić za mało ['za dużo']
# WA:  150 ['w dziewięćdziesiąt', '90']
# WA:  hipokrates żył wcześniej ['hipokrates']
# WA:  kaczor ['kulfon']
# WA:  może się zdarzyć wszystko ['wszystko']
# WA:  trzecia wojna punicka ['żadna']
# WA:  jan klata ['zygmunta hübnera', 'hübnera']
# WA:  50 ['50 hz', '50 herców']
# WA:  nie ['do niemiec']
# WA:  wojska austriackie ['z austriakami', 'z austrią']
# WA:  włochy ['z węgier', 'węgry']
# WA:  św jan chrzciciel ['piłat']
# WA:  wymiana barterowa ['barter']
# WA:  bzura ['nad pilicą']
# WA:  miarą w dawnej polsce była włóka ['powierzchni', 'ziemi']
# WA:  rezystor ['opornik']
# WA:  złota i czerwona ['czerwonego']
# WA:  20 ['dziesięć', '10']
# WA:  król zygmunt iii waza ['jana karola chodkiewicza']
# WA:  1994 ['„familiadę”']
# WA:  państwowe gospodarstwo rolne ['kołchoz']
# WA:  judaizm ['w islamie']
# WA:  gruzja ['ormiańskiej', 'ormianin']
# WA:  car puszka w kremlu ['na kremlu']
# WA:  santo domingo ['w gdańsku']
# WA:  w krakowie ['krakowa']
# WA:  kopie ['pika']
# WA:  braveheart ['serce']
# WA:  generał broni ['marszałek polski']
# WA:  ewangelia oznacza dobrą nowinę lub dobrą wiadomość ['dobra nowina']
# WA:  sępy ['tygrysy']
# WA:  trujący ['czad']
# WA:  janosik ['józef bem']
# WA:  starszy marynarz ['bosman']
# WA:  himalajski żywotnik ['bambus']
# WA:  hieron ii ['archimedes']
# WA:  lawrence welk był kierownikiem orkiestry ['glenn miller']
# WA:  giacomo puccini ['niccolò paganini']
# WA:  werner klemperer ['stanisław mikulski']
# WA:  autobus zasilany siecią ['trolejbus']
# WA:  "wesele" stanisława wyspiańskiego ['z „warszawianki”']
# WA:  ropa naftowa i gaz ziemny ['ropa naftowa']
# WA:  terapia surowicą obojętną ['placebo']
# WA:  johnny weissmuller zagrał tarzana w filmie irvinga thalberga ['tarzana']
# WA:  aby wygrać szlema w brydżu ['wszystkie', 'trzynaście', '13']
# WA:  prasowanie parowe ['dekatyzacja']
# WA:  kapitanem łodzi podwodnej w powieści juliusza verne'a „dwadzieścia tysięcy mil podmorskiej żeglugi” był kapitan ['nemo']
# WA:  gerwazy był klucznikiem horeszków ['horeszków']
# WA:  jerzy grotowski ['henryk tomaszewski']
# WA:  "kto zgadnie ['„wielka gra”']
# WA:  japonia i chiny ['japonii']
# WA:  muzeum egipskim w londynie ['w muzeum brytyjskim', 'w british museum']
# WA:  kolumna ['stalagnat']
# WA:  europa ['w azji', 'azja']
# WA:  georg ohm był niemcem ['niemieckiej', 'był niemcem']
# WA:  zygmunt ii august ['zygmunt iii waza']
# WA:  sir howard grubb ['jan heweliusz']
# WA:  klarnet ['na klarnecie']
# WA:  berezyna ['przez berezynę']
# WA:  3 ['z dwóch', 'z dwu', '2']
# WA:  hannibal barca ['hannibal']
# WA:  kwas octowy jest organicznym związkiem chemicznym ['mlekowy']
# WA:  bakłażan nazywany jest również bakłażanem ['oberżyna']
# WA:  1993 ['w 1991']
# WA:  guillotine ['gilotyna']
# WA:  polska ['w polsce']
# WA:  1889 ['od 1890']
# WA:  „romeo i julia” williama shakespeara ['do romea i julii', 'romeo i julia']
# WA:  hefajstos wykuł wspaniałą zbroję na prośbę tetydy ['achillesowi']
# WA:  "z radością witam wszystkich polaków" ['„żeby polska była polską”']
# WA:  liczba podniesiona do trzeciej potęgi nazywa się sześcianem ['sześcianem']
# WA:  klasztorny dziedziniec ['wirydarz']
# WA:  wlazł na płotek ['na płotek']
# WA:  pesymizm ['manko', 'niedobór']
# WA:  1 ['łunochod']
# WA:  wołodyjowski nosił imię michał ['michał']
# WA:  babilończycy i sumerowie posługiwali się pismem klinowym ['klinowym']
# WA:  biedny jak mysz kością rzucona ['kościelna']
# WA:  100 ['pięćset', '500']
# WA:  krakus ['lajkonik']
# WA:  bociany są ptakami mięsożernymi ['mięsożernymi']
# WA:  wszystko ['fortuna']
# WA:  leipzig ['pod lipskiem', 'lipsk']
# WA:  pięciu ['trzech', '3']
# WA:  porucznik ['rotmistrz']
# WA:  andrzej bursa ['leopold tyrmand']
# WA:  1928 ['w xx', '20']
# WA:  wszystkie wymienione metropolie są „warte mszy” ['paryż']
# WA:  nasiona następcze ['oziminy']
# WA:  nie ['witaminy a', 'a']
# WA:  czerwiec ['w lipcu']
# WA:  48 ['dwie', '2']
# WA:  k ['na literę a', 'na a', 'a']
# WA:  w afryce ['przez afrykę', 'afryka']
# WA:  polegać na sukcesie ['na laurach']
# WA:  era mezozoiczna ['mezozoik']
# WA:  afryka ma większą powierzchnię ['afryka']
# WA:  mniejszość litewska ['litewskiej']
# WA:  owady ['przeciwko muchom', 'muchom']
# WA:  korniki ['termity']
# WA:  - ['beżowy']
# WA:  podstawa logarytmu ['cecha']
# WA:  paul doumer ['charles de gaulle', 'de gaulle']
# WA:  ryszard kaczorowski przekazał insygnia władzy ii rzeczypospolitej sobie samemu ['lechowi wałęsie', 'wałęsie']
# WA:  - ['wielkie uderzenie', 'mocne uderzenie']
# WA:  magisterium sine diploma ['absolutorium']
# WA:  afrodyta ['psyche']
# WA:  mikołaj rej był kalwinem ['kalwinem']
# WA:  ministerstwo spraw wewnętrznych w warszawie ['w zachęcie', 'w gmachu zachęty', 'zachęta']
# WA:  skorpion i kameleon są gady ['kameleon']
# WA:  szarfę ['serce']
# WA:  mieczysław cybulski ['kazimierz junosza-stępowski']
# WA:  paria ['dalit']
# WA:  sankt petersburg ['petersburga']
# WA:  79 ['w xix', '19']
# WA:  tak ['nie']
# WA:  klitajmestra ['stentor']
# WA:  logomachia to jałowy spór o słowa lub pojęcia ['o słowa']
# WA:  "ogniem i mieczem" ['w „quo vadis”']
# WA:  akredytacja ['nostryfikacja']
# WA:  tak ['nie']
# WA:  generał józef haller ['tadeusz kościuszko']
# WA:  trzecia rzesza ['trzeciej', '3']
# WA:  bzura ['nad wisłą']
# WA:  generał józef haller ['józef haller']
# WA:  stary testament składa się z większej ilości ksiąg ['stary testament', 'stary']
# WA:  antytetyka ['oksymoron']
# WA:  pokrzywa parzy włoskami ['włoskami']
# WA:  lufa ['panewka']
# WA:  jednostka kelvina jest jednostką temperatury ['temperatury']
# WA:  jezioro aralskie ['morze kaspijskie']
# WA:  51 ['w xvii', '17']
# WA:  partia socjalistyczna hiszpanii ['hiszpańskiej socjalistycznej partii robotniczej']
# WA:  maxence van der meersch ['jarosława iwaszkiewicza']
# WA:  wprowadzić kogoś w błąd lub wymanipulować go ['w pole']
# WA:  obieg wenus wokół słońca trwa dłużej niż obrót wokół własnej osi ['obrót wokół własnej osi']
# WA:  pies ['wiewiórkę']
# WA:  janusz lewandowski ['wiesław rozłucki']
# WA:  gołębie pocztowe ['sowy']
# WA:  vaslav nijinsky ['wacław niżyński']
# WA:  1990 ['do 1991']
# WA:  atlantycki ocean jest większy ['ocean atlantycki', 'atlantyk']
# WA:  gospodyni ['gaździna']
# WA:  maria callas była zawodową śpiewaczką operową ['śpiewaczką operową']
# WA:  związek radziecki ['albania']
# WA:  adam mickiewicz ['mikołaj rej', 'rej']
# WA:  traktat wersalski zakończył i wojnę światową ['i wojnę światową']
# WA:  krzemionka ['talk']
# WA:  wyrażenie językowe ['idiom']
# WA:  woda składa się z trzech atomów ['trzy', '3']
# WA:  umowa o wynajem samolotu ['czarter']
# WA:  dynastia glücksburg ['glücksburgowie', 'schleswig-holstein-sonderburg-glücksburg']
# WA:  anton antonowicz chlestakow ['chlestakow']
# WA:  michał wołodyjowski ['tuhaj-bej']
# WA:  czechy ['w czechach']
# WA:  polska ['w polsce']
# WA:  herbert hoover ['woodrow wilson']
# WA:  4 ['jeden raz', 'raz', '1']
# WA:  kukułki ['żurawie']
# WA:  26 ['w xix', '19']
# WA:  1795 ['w xii', '12']
# WA:  głównym motywem w dramacie aleksandra fredry „zemsta” jest zemsta cześnika raptusiewicza na rejentzie milczku ['o mur graniczny', 'o mur']
# WA:  1209 ['w xiii', '13']
# WA:  na krzyż ['równolegle']
# WA:  zbigniew pietrzykowski ['jerzy kulej']
# WA:  kaftan bezpieczeństwa ma długość do kostek ['rękawy']
# WA:  - ['austro-węgry']
# WA:  słodki ['nie ma zapachu', 'jest bezwonny']
# WA:  miecz zawieszony na sznurku ['miecz']
# WA:  1955 ['w 1901']
# WA:  słońce znajduje się wewnątrz układu planetarnego ['wewnątrz']
# WA:  dzwon zygmunta jest starszy ['dzwon zygmunta']
# WA:  teoria relatywizmu ['relatywizm']
# WA:  "ludzie bezdomni" ['„popioły”']
# WA:  wrzesień ['we wrześniu']
# WA:  walne zgromadzenie akcjonariuszy ['walne zgromadzenie']
# WA:  opłaty mostowe ['myto']
# WA:  5 ['cztery', '4']
# WA:  w krakowie ['w częstochowie']
# WA:  rudolf nureyev ['michaił barysznikow']
# WA:  paul von hindenburg ['otto von bismarck']
# WA:  fitofagi to zwierzęta roślinożerne ['zwierzęta roślinożerne']
# WA:  archanioł ['serafin']
# WA:  1683 ['w xvii', '17']
# WA:  zygmunt iii waza ['władysław iv waza']
# WA:  tak ['nie']
# WA:  1920 ['w 1660']
# WA:  liczba dzielna ['dzielnik']
# WA:  bob vila ['adam słodowy']
# WA:  1864 ['w xix', '19']
# WA:  cynk ['złoto']
# WA:  cyceron twierdził ['jego drugą naturą', 'drugą naturą człowieka']
# WA:  ruch polska akcja solidarności ['bezpartyjny blok wspierania reform', 'bbwr']
# WA:  mielec ['w świdniku']
# WA:  ignacy z loyoli ['loyola']
# WA:  oktagon ['styczna']
# WA:  wielokropek ma trzy kropki ['trzy', '3']
# WA:  wyspa malta ['maltę']
# WA:  węgry ['na węgrzech']
# WA:  jezioro bajkał ['bajkał']
# WA:  jan matejko ['rembrandt van rijn']
# WA:  stanisław august poniatowski ['władysława ii jagiełły', 'jagiełły']
# WA:  naukowy komentarz do wyroku sądowego ['glosa']
# WA:  prawo ['medycynę']
# WA:  infanticyd ['dzieciobójstwo']
# WA:  william szekspir ['molier', 'jean baptiste poquelin']
# WA:  gród biskupin ['biskupin']
# WA:  oceany nie sąsiadują ze sobą ['tworzą jedną całość']
# WA:  zapalenie płuc ['suchoty', 'gruźlica']
# WA:  spółgłoska podwojona to „n” ['geminata']
# WA:  jodyna jest roztworem jodu w wodzie ['w alkoholu']
# WA:  aparat słuchowy ['trąbka eustachiusza']
# WA:  stanisław leszczyński ['zygmunt iii waza']
# WA:  twarz ['nogi', 'nogi roztańczone']
# WA:  kermit the frog ['kermit']
# WA:  ma przewagę ['się śmieje ostatni']
# WA:  ania dąbrowska ['anita lipnicka']
# WA:  atena urodziła się w zbroi ['w zbroję']
# WA:  cera ['w wosku']
# WA:  tristan ['króla kornwalii marka', 'marka']
# WA:  austria ['z polski']
# WA:  tania ['marusia']
# WA:  świnki morskie ['do glonojadów', 'glonojad']
# WA:  zdolności matematycznych ['liczenia']
# WA:  statek kosmiczny transportowy ['wahadłowiec kosmiczny']
# WA:  złoty potok ['okocim']
# WA:  10 ['jedna dziesiąta', '10.01.2021', '0,1']
# WA:  tapiry to ssaki ['ssaki']
# WA:  narew ['nad białą']
# WA:  starosta zarządza powiatem ['powiatem']
# WA:  czarny staw ['morskie oko']
# WA:  feudał ['suweren']
# WA:  matka persefony ['siostrą']
# WA:  zespół muzyczny elf ['„varius manx”']
# WA:  nikita chruszczow ['gieorgij malenkow']
# WA:  - ['żeńcy']
# WA:  kuzyni ['byli braćmi', 'bracia']
# WA:  karol wielki był twórcą potęgi karolingów ['karol młot']
# WA:  141 ['czarna procesja']
# WA:  wygnanie ['banicja']
# WA:  dalekowidz nosi soczewki skupiające ['skupiające']
# WA:  umowa laterańska ['konkordat']
# WA:  wyspa lampedusa należy do włoch ['do włoch']
# WA:  „the merry widow” ['„wesoła wdówka”']
# WA:  "philadelphia" ['„forrest gump”']
# WA:  kacper łuczyński ['wilk']
# WA:  6 ['6 stycznia']
# WA:  flamandowie mają więcej mieszkańców ['flamandowie']
# WA:  morze śródziemne ['oceanu atlantyckiego', 'atlantyku']
# WA:  kwiecień ['w kwietniu']
# WA:  usuwanie wody ['wody']
# WA:  karol iv ['most karola', 'karola vi']
# WA:  przeżu ['gryzoniem']
# WA:  anonimowy arabski autor ['szeherezada']
# WA:  zbiornik solina ['jezioro solińskie']
# WA:  beskid żywiecki ['w tatrach', 'tatry']
# WA:  operacja barbarossa ['barbarossa']
# WA:  nie ['zawsze ujemną', 'ujemną']
# WA:  z tetralogii składa się cztery utwory literackie ['z czterech', '4', '4']
# WA:  muchówki ['do ważek', 'ważki']
# WA:  układ okresowy pierwiastków składa się z siedmiu okresów ['z siedmiu']
# WA:  prawa burta ['lewa']
# WA:  nogat ['nad nogatem']
# WA:  pałac poniatowskich ['pałac pod blachą']
# WA:  stanisław august poniatowski ['zygmunta ii augusta']
# WA:  24 ['w xvi', '16']
# WA:  nie ['tak']
# WA:  pierścionek ['bransoleta']
# WA:  anolis ['kameleon']
# WA:  linia atlantyku ['wał atlantycki']
# WA:  stanisław august poniatowski ['kazimierz wielki']
# WA:  milczenie jest złotem ['złotem']
# WA:  narząd wzroku ['wzroku', 'oka', 'oczu']
# WA:  jan kasprowicz ['mikołajowi rejowi', 'rejowi']
# WA:  zawołanie „eviva l'arte!” oznacza „niech żyje sztuka!” ['„niech żyje sztuka!”']
# WA:  hiszpania ['z francji']
# WA:  jan peszek ['pawlik', 'bronisław pawlik']
# WA:  nurembergskie ustawy rasy ['ustawy norymberskie']
# WA:  9-11 ['trzydzieści', '30']
# WA:  znak ten oznacza postój ['parking']
# WA:  colorado potato beetle ['stonka ziemniaczana']
# WA:  gdańsk ['w 1959']
# WA:  mitologiczny ['brytanii']
# WA:  proces ten nazywa się diageneza ['fosylizacja']
# WA:  taras szewczenko ['wernyhora']
# WA:  kaedwen ['z rivii', 'rivia']
# WA:  instynkty polowania ['natura']
# WA:  scrutin secret ['balotaż']
# WA:  stała ['ciekłą']
# WA:  zygmunt i stary ['zygmunt ii august']
# WA:  balzac był francuzem ['był francuzem', 'francuskiej']
# WA:  41 ['w xvi', '16']
# WA:  fiołek ['tatuś muminka']
# WA:  „dziady” powstały wcześniej ['„pan tadeusz”']
# WA:  wzrost giełdowy ['hossa']
# WA:  alfa ['alfa, beta, gamma']
# WA:  tak ['nie']
# WA:  ostrze krojące ['lemiesz']
# WA:  oficer dyspozycyjny ['adiutant']
# WA:  erupcja wulkaniczna ['lawa']
# WA:  znaki chromatyczne stawiane są nad ['przed nutą']
# WA:  tipi ['wigwam']
# WA:  krokodyle są jajorodne ['jajorodne']
# WA:  "gorzka miłość" ['„niewolnica isaura”']
# WA:  hoplitowie ['hoplici']
# WA:  - ['krystyna chojnowska-liskiewicz']
# WA:  islam jest najbardziej dominującą religią w indonezji ['islamu']
# WA:  andrzej wajda zadebiutował w kinie wcześniej ['andrzej wajda', 'wajda']
# WA:  tak ['nie']
# WA:  broń palna ['siecznej']
# WA:  „porwanie baltazara gąbki” ['„rumcajs”']
# WA:  wróbel ['z kaczką']
# WA:  zygmunt stary ['bolesław ii śmiały']
# WA:  6 ['przed trzynastą', '13']
# WA:  3 ['pięć', '5']
# WA:  polska ['w polsce']
# WA:  10000 ['większa']
# WA:  64 ['trzydzieści dwa', '32']
# WA:  faust ['mefistofeles', 'diabeł']
# WA:  w afryce ['w azji', 'azja']
# WA:  barometr ['barograf']
# WA:  skoki narciarskie ['w rzucie oszczepem']
# WA:  biblioteka narodowa w warszawie ['biblioteka narodowa']
# WA:  rosja ['z wojskami szwecji', 'szwecji']
# WA:  eksport to wywóz za granicę towarów ['wywóz za granicę']
# WA:  skurczowe ciśnienie krwi jest wyższe ['skurczowe']
# WA:  jednostka stratygraficzna ['oddział']
# WA:  5 ['sześć', '6']
# WA:  onomatopeja to dźwiękonaśladownictwo ['dźwiękonaśladownictwo']
# WA:  część iii ['w trzeciej', '3']
# WA:  jan dworak ['marek markiewicz']
# WA:  uniwersytet ekonomiczny w krakowie ['szkoła główna handlowa']
# WA:  sekwana jest dłuższa ['wisła']
# WA:  prowincje ['regiony']
# WA:  degradacja tworzyw ['korozja']
# WA:  żniwa ['dożynki']
# WA:  janusz ['wojciech']
# WA:  sztokfisz to gatunek ryby z rodziny dorszowatych ['dorsz', 'dorszowate']
# WA:  fleksja czasownika ['koniugacja']
# WA:  okulary przylegające do twarzy ['gogle']
# WA:  władysław jagiełło ['kazimierz wielki']
# WA:  warstwa wyróżniająca ['ławica']
# WA:  nie ['tak']
# WA:  obiekt okrążający to satelita ['satelita']
# WA:  krawędź ['wybrzeże', 'brzeg']
# WA:  w afryce ['ameryki południowej', 'ameryki płd.']
# WA:  jakub szczęsny ['jankiel']
# WA:  wciągarka do pali ['kafar']
# WA:  rzeka i góra ['za siódmą', 'za siedmioma', '7']
# WA:  fryderyk wilhelm iii ['zygmunta i starego']
# WA:  tak ['nie']
# WA:  natalia nykiel ['alicja majewska']
# WA:  ssak ['ptakiem']
# WA:  we włoszech ['z włoch']
# WA:  dwudziestościan foremny ma więcej wierzchołków ['dwunastościan']
# WA:  jabłko ['kokosa']
# WA:  przekaz pieniężny ['czek']
# WA:  frank szwajcarski i euro ['szwajcarii']
# WA:  3 ['w około trzy sekundy', 'w 3 sekundy', '3 s']
# WA:  3 ['z dwóch', 'z dwu', '2']
# WA:  józef poniatowski ['fryderyka chopina', 'chopina']
# WA:  4 ['żadnego']
# WA:  królowa bona zmarła na zatrucie pokarmowe ['została otruta']
# WA:  gurkha ['szerpowie']
# WA:  na oceanie spokojnym ['hawajów']
# WA:  6 ['pięć', '5']
# WA:  król michał korybut wiśniowiecki ['kmicic']
# WA:  krzyżówka krzyżykowa ['jolka']
# WA:  cieśnina bosfor ['bosfor']
# WA:  hel ['wodór']
# WA:  jan paweł ii ['jan paweł']
# WA:  stary sejm w warszawie ['w zamku królewskim', 'na zamku']
# WA:  wodzowie macedońscy ['diadochowie']
# WA:  szyperzy ['szyprowie']
# WA:  bois de boulogne ['lasek buloński']
# WA:  yakuza to mafia japońska ['japońska']
# WA:  nocna miopia ['kurza ślepota']
# WA:  tak ['nie']
# WA:  rezystor termistora ['termistor']
# WA:  powstanie listopadowe ['w powstaniu styczniowym', 'styczniowym']
# WA:  „suprema lex” oznacza „najwyższy prawdziwy” ['najwyższe prawo']
# WA:  kazimierz wielki ['aleksander jagiellończyk']
# WA:  - ['w krynicy-zdroju']
# WA:  kaukaz ['ural']
# WA:  halina ołomucka ['pelagia majewska']
# WA:  taniec czardasza ['czardasz']
# WA:  alfabet cyrylica powstał wcześniej ['grażdanka']
# WA:  stany zjednoczone ['w polsce']
# WA:  1981 ['w 1982']
# WA:  tak ['nie']
# WA:  prezydent polski ['prezydent rp']
# WA:  michelangelo ['michał anioł']
# WA:  saksofon jest instrumentem dętym blaszanym ['dęty drewniany']
# WA:  kontrabas jest największym instrumentem smyczkowym ['kontrabas']
# WA:  1908 ['w xx', '20']
# WA:  ryszard iii chciał oddać swoje królestwo w zamian za pokój ['za konia', 'koń']
# WA:  "ludzie bezdomni" ['„wierna rzeka”']
# WA:  królowa wiktoria ['wiktoria']
# WA:  aleksander fredro ['molier', 'jean baptiste poquelin']
# WA:  gruziński ['był gruzinem', 'gruzin']
# WA:  "czterej pancerni i pies" ['„07 zgłoś się”']
# WA:  benjamin ['józef']
# WA:  wędlina jałowcowa i myśliwska ['kiełbasa']
# WA:  "ludzie bezdomni" ['„syzyfowe prace”']
# WA:  warszawa ['w krakowie']
# WA:  sufler pomaga aktorom przypominać sobie tekst ['podpowiadaniem aktorom']
# WA:  reakcja endoenergetyczna ['endotermiczna']
# WA:  kość szczękowa ['żuchwa']
# WA:  sarolta ['sylwia', 'sylvia']
# WA:  stronnictwo pracy ['proletaryat']
# WA:  instrument ['gra']
# WA:  - ['kogel-mogel']
# WA:  trzej królowie ['o pasterzy']
# WA:  80 ['w xx', '20']
# WA:  jezioro bajkał ['ładoga']
# WA:  pkn ['cpn']
# WA:  nie ['tak']
# WA:  natężenie prądu płynącego w każdej z nich jest jednakowe ['jednakowe']
# WA:  stan nieważkości ['nieważkość']
# WA:  rożen ['sękacz']
# WA:  pomnik adama mickiewicza ['na cokole pomnika grunwaldzkiego']
# WA:  kadzidło ['bursztyn']
# WA:  lotniskowiec ['log']
# WA:  jan sebastian bach żył wcześniej ['jan sebastian bach', 'bach']
# WA:  jacek kurski ['ryszard miazek']
# WA:  generał michaił kutuzow ['michaił kutuzow']
# WA:  przewodniczący sejmu ['marszałek sejmu']
# WA:  mime ['pantomima']
# WA:  trybuna ludu ['„sztandar młodych”']
# WA:  smerfeta ['laluś']
# WA:  drugi dzień lutego ['trzydziesty drugi', '32']
# WA:  warszawa ['w sopocie', 'sopot']
# WA:  największe bezkręgowce świata to kalmary i rekiny ['kałamarnice olbrzymie']
# WA:  polska ['na białorusi']
# WA:  długi ['długim nosem']
# WA:  król władysław łokietek był przodkiem księcia leszka czarnego ['bratem']
# WA:  rod ['świętowit', 'światowid']
# WA:  pikle sporządza się z warzyw ['z warzyw']
# WA:  pierwsza dama ['primadonna']
# WA:  janusz ['jacek']
# WA:  dziurawiec zwyczajny ['mandragora lekarska']
# WA:  gregor wielki ['grzegorz i']
# WA:  kłus zmieniony skrócony wolny ['stęp']
# WA:  dotyczące ruchu przyspieszonego ['twierdzenie geometryczne']
# WA:  roy urquhart ['stanisław sosabowski']
# WA:  - ['auguste renoir', 'renoir']
# WA:  księga jozuego ['księga powtórzonego prawa', 'deuteronomium']
# WA:  motyw malarski ['pejzaż']
# WA:  poduszka pod suknią ['turniura']
# WA:  świat to za mało ['„śmierć nadejdzie jutro”']
# WA:  warszawa ['w gliwicach']
# WA:  1791 ['konstytucja 3 maja']
# WA:  krew jest przetłaczana z przedsionków do komór ['z przedsionków do komór']
# WA:  przygody koziołka matołka ['„szatan z 7 klasy”']
# WA:  wyspa malta ['irlandia']
# WA:  nie ['tak']
# WA:  tak ['nie']
# WA:  złote pszczoły ['pszczoły merowingów']
# WA:  erozja wietrzna ['deflacja']
# WA:  nie ['baśka']
# WA:  plantacja ['sad']
# WA:  nie ['na niedźwiedziu']
# WA:  7368 ['w xiv', '14']
# WA:  the great dictator ['„dyktator”']
# WA:  sabrina salerno ['sabrina']
# WA:  jan długosz ['wincenty kadłubek']
# WA:  stanisław wyspiański ['magdalena samozwaniec']
# WA:  wojsko czerwone ['armia czerwona']
# WA:  kościół mariacki ma dwie wieże ['dwie', '2']
# WA:  skok wzwyż ['w trójskoku']
# WA:  79 ['w i', '1']
# WA:  rzeka syr darya ['jangcy']
# WA:  - ['bór-komorowski']
# WA:  estry ['mydła']
# WA:  pogrzebem achilleusza kończy się akcja „iliady” ['hektora']
# WA:  flecistą ['fletem']
# WA:  24-28 ['w pierwszym', 'w i']
# WA:  stanisław wojciechowski ['ignacy mościcki']
# WA:  na piersi ['w klapie']
# WA:  probówka ['pipeta']
# WA:  historii ['rejestr']
# WA:  assam ['indii']
# WA:  42 ['w xv', '15']
# WA:  elektrokardiografia rejestruje prądy w mięśniu sercowym ['prądy w mięśniu sercowym']
# WA:  henryk sienkiewicz ['maria rodziewiczówna']
# WA:  eudajmonizm ['hedonizm']
# WA:  nadludzka siła ['sok z gumijagód', 'gumijagody']
# WA:  "lalka" ['„emancypantki”']
# WA:  król august ii mocny ['stanisław konarski']
# WA:  fryderyk chopin ['giacomo puccini', 'puccini']
# WA:  janek krzeptowski ['sabała']
# WA:  szarik ['saba']
# WA:  polska ['w polsce']
# WA:  cielę ssie obie matki ['pokorne']
# WA:  kora ['z kory']
# WA:  tamiza ['na tamizie']
# WA:  w czaszce ['w nosie']
# WA:  słoń afrykański ma większe uszy ['afrykańskie']
# WA:  - ['halina czerny-stefańska']
# WA:  przypadek bierny ['miejscownik']
# WA:  w krakowie ['ze szczecina']
# WA:  kōbō abe ['joanna chmielewska']
# WA:  stanów zjednoczonych ['kanady']
# WA:  stanisław wyspiański ['eliza orzeszkowa']
# WA:  porucznik ['kapitana']
# WA:  ateny ['w atenach']
# WA:  edyta górniak ['karin stanek']
# WA:  tak ['wielościany foremne']
# WA:  pośrednik rynku wtórnego ['makler papierów wartościowych', 'makler']
# WA:  djellaba ['burnus']
# WA:  najpierw miniemy toruń ['toruń']
# WA:  j ['brazylia']
# WA:  lonża ['arkan']
# WA:  republika wyzwolenia ludowego burkina faso ['górna wolta']
# WA:  josefa ['józefina']
# WA:  matiasz ['maciej']
# WA:  województwo podlaskie ['w mazowieckim']
# WA:  canossa we włoszech ['w kanossie']
# WA:  uniform ['liberia']
# WA:  1798 ['w xviii', '18']
# WA:  johann sebastian i georg philipp ['jan sebastian']
# WA:  ernest hemingway ['andrzej szczypiorski']
# WA:  29301934 ['noc długich noży']
# WA:  orange ['pomarańczowy']
# WA:  kuzyni ['są braćmi', 'bracia']
# WA:  kwas siarkowy ['azotowego']
# WA:  remisja oznacza okresowe ustąpienie objawów choroby ['ustąpienie objawów', 'ustąpienie']
# WA:  jazda na rowerze górskim ['kolarstwo górskie']
# WA:  wielka wieś ['zapiecek']
# WA:  liczba mnoga słowa „człowiek” to „ludzie” ['ludzie']
# WA:  83 ['w xix', '19']
# WA:  wielki wóz ['małej niedźwiedzicy']
# WA:  jezus przemienił wodę w wino ['wodę']
# WA:  słupki ['kliważ']
# WA:  111977 ['„ben-hur”']
# WA:  1989 ['w 1959']
# WA:  warszawa ['w żelazowej woli']
# WA:  władysław reymont ['isaac bashevis singer', 'singer']
# WA:  al capone działał w chicago w stanie illinois ['w chicago']
# WA:  w azji ['z ameryki południowej', 'z ameryki płd.']
# WA:  odra ['wełtawa']
# WA:  ragnaroek ['ślęża']
# WA:  liczebnik porządkowy ['liczebnik']
# WA:  włochy ['watykanu']
# WA:  lampa elektronowa czteroelektrodowa ['tetroda']
# WA:  ośmioro ['osiem', '8']
# WA:  halerz był częścią korony austriackiej ['jedną setną', 'setną', '0,01']
# WA:  ramienia ['z młodej']
# WA:  delfiny używają ultradźwięków ['ultradźwięków']
# WA:  wojciech jaruzelski ['kazimierz barcikowski']
# WA:  syberia ['w ameryce północnej', 'ameryka płn.']
# WA:  neon ma kilka kolorów ['jest bezbarwny', 'żaden', 'nie ma koloru']
# WA:  26 ['z dwudziestu trzech', '23']
# WA:  polska ['na terenie słowenii', 'w słowenii']
# WA:  wazony ['wachlarz']
# WA:  choroba nowotworowa ['suchoty', 'gruźlica']
# WA:  skibob służy do poruszania się po śniegu ['po śniegu']
# WA:  "pictures at an exhibition" ['„obrazki z wystawy”']
# WA:  lord byron ['george gordon byron', 'byron']
# WA:  sanatio oznacza uzdrowienie ['uzdrowienie']
# WA:  john travolta i nicolas cage ['robert redford i paul newman', 'paul newman i robert redford', 'redford i newman', 'newman i redford']
# WA:  legendarna wyspa atlantyda ['o atlantydzie']
# WA:  język niemiecki ['z niemieckiego']
# WA:  9 ['nigdy', 'wcale', 'zero', '0']
# WA:  świątynia jerozolimska ['salomona', 'jerozolimskiej']
# WA:  drobiu ['z wieprzowiny']
# WA:  opiekunowie zastępczy ['kochanki']
# WA:  system dziesiętny i cyfry arabskie zostały wynalezione przez arabów ['w indiach']
# WA:  stanisław wyspiański ['stefana jaracza', 'jaracza']
# WA:  sherlock holmes ['kojaka', 'theo kojaka']
# WA:  żadne ['gruszki']
# WA:  język grecki ['greckiego', 'greki']
# WA:  5 ['trzydzieści pięć', '35']
# WA:  nie ['we włoszech', 'włochy']
# WA:  jezioro hańcza ['hańcza']
# WA:  mikołaj ii ['mikołaj ii aleksandrowicz romanow']
# WA:  kaleb ['ramzes']
# WA:  2 ['1 kg', 'kilogram']
# WA:  prawo do wolności i niezawisłości ['konstytucja', 'konstytucja rzeczypospolitej polskiej']
# WA:  1674 ['w xvi', '16']
# WA:  magistrat mst warszawy ['w pałacu namiestnikowskim']
# WA:  międzynarodowa organizacja policji kryminalnej (interpol) ['interpol']
# WA:  perfect ['łucja prus', 'prus']
# WA:  cieśnina świna ['świna']
# WA:  morze północne i morze bałtyckie ['nad morzem północnym', 'północnym']
# WA:  bobry ['dziki']
# WA:  postanowienie o tymczasowym aresztowaniu ['list gończy']
# WA:  scarabaeus sacer ['skarabeusza']
# WA:  order złotej róży ['order orła białego']
# WA:  kiełkuje ['cisza']
# WA:  władimir kuc ['serhij bubka', 'bubka']
# WA:  anna maria ['ewa']
# WA:  richeza z lotharingii ['oda dytrykówna']
# WA:  elipsa ma dwa osi symetrii ['dwie', '2']
# WA:  czechy ['w czechach']
# WA:  ręczny wagonik szynowy ['drezyna']
# WA:  usa ['w kanadzie']
# WA:  londyn ['na cmentarzu monte cassino', 'pod monte cassino']
# WA:  2002 ['„ogniem i mieczem”']
# WA:  „galileo ['galilejczyku, zwyciężyłeś!']
# WA:  hugon i ['hugo kapet']
# WA:  konstytucja marcowa została uchwalona wcześniej ['marcowa']
# WA:  perskie siły wojskowe ['persów']
# WA:  "the merry widow" (wesoła wdowa) ['„wesoła wdówka”']
# WA:  6 ['trzy', '3']
# WA:  endoproteza jest umieszczana wewnątrz ciała ['wewnątrz ciała']
# WA:  tak ['rowerzysta']
# WA:  włóczęga ['martin eden']
# WA:  nic ['ogarek']
# WA:  armada króla filipa ii ['wielka armada']
# WA:  warta ['nad wartą']
# WA:  1991 ['w xx', '20']
# WA:  spike ['wolej']
# WA:  jan pietrzak ['jonasz kofta', 'kofta']
# WA:  spadek aktywności życia gospodarczego określa się jako recesję ['recesja']
# WA:  stany zjednoczone ['w los angeles']
# WA:  pogląd analogii ['aktualizm']
# WA:  brytyjski arystokrata ['uwodziciela']
# WA:  badanie odcisków palców ['daktyloskopia']
# WA:  krzyż srebrny orderu virtuti militari ['warszawski krzyż powstańczy']
# WA:  symbol "p" ['126p']
# WA:  kazimierz jagiellończyk ['kazimierza wielkiego']
# WA:  jednoręki bandyta ['bandyta']
# WA:  królestwo prus ['do szwecji']
# WA:  niższe warstwy społeczne ['z chłopstwa', 'chłopi']
# WA:  monachium ['w tokio']
# WA:  monachium ['w niemczech']
# WA:  natężenie prądu elektrycznego ['napięcie elektryczne', 'napięcie']
# WA:  krzysztof ibisz ['tomasz hopfer', 'hopfer']
# WA:  chester wiliam nimitz był głównodowodzącym sił morskich stanów zjednoczonych podczas ii wojny światowej ['dowódca floty stanów zjednoczonych na pacyfiku', 'dowódca floty usa']
# WA:  325 ['w iv']
# WA:  erich hoepner ['hodon', 'margrabia hodon']
# WA:  bitwa pod gorzowem ['pod legnicą']
# WA:  walpurgisnacht ['sabat']
# WA:  kruki są ptakami poligamicznymi ['monogamiczne']
# WA:  armia krajowa ['organizacji harcerzy zhp', 'związku harcerstwa polskiego', 'harcerzy']
# WA:  cyprian norwid ['żaden']
# WA:  spadek ['bessa']
# WA:  mezozoiczna ['kenozoiku']
# WA:  820 ['8 minut i 20 sekund', '8 minut']
# WA:  king cobra ['królewska']
# WA:  amazonka ['do atlantyku', 'do atlantyckiego']
# WA:  wyciskanie rowków ['bigowanie']
# WA:  the beatles ['trubadurzy']
# WA:  wychowawczyni i nauczycielka ['guwernantką']
# WA:  głagolicę stworzył cyryl i metody ['św. cyryl', 'cyryl i metody']
# WA:  stanisław august poniatowski ['józef i andrzej załuscy', 'załuscy']
# WA:  gdańsk ['kaliningrad']
# WA:  zupa kacza ['czernina']
# WA:  żonatym ['być zaręczonym']
# WA:  62 ['w iv p.n.e.']
# WA:  1573 ['w xiv', '14']
# WA:  każdy partner ma tylko jednego małżonka ['jednego', '1']
# WA:  miliony ['kamienie milowe']
# WA:  andrzej sapkowski ['melchior wańkowicz']
# WA:  fusion ['jazz-rock']
# WA:  elżbieta i tudor nie miała ślubnych dzieci ['żadnych', 'zero']
# WA:  tak ['obligacja']
# WA:  warszawski festiwal muzyki współczesnej ['„warszawska jesień”']
# WA:  nie ['a sam smoli']
# WA:  4 ['„ranczo”']
# WA:  rosja ['francji', 'francuskie']
# WA:  30 ['w xv', '15']
# WA:  cholera jest chorobą bakteryjną ['bakteryjna']
# WA:  zasada dynamiki newtona ['trzeciej', '3']
# WA:  tango jest tańcem latynoamerykańskim ['do standardowych']
# WA:  12 ['dwadzieścia cztery', '24']
# WA:  yulianna avdeeva ['krystian zimerman']
# WA:  w serialu „stawka większa niż życie” najlepsze były kluby ['kasztany']
# WA:  isis ['izyda']
# WA:  sztućce ['łyżka i widelec', 'widelec i łyżka']
# WA:  erich von däniken ['wojciech żukrowski']
# WA:  każda liczba pierwsza ma tylko dwa dzielniki ['dwa', '2']
# WA:  wyspa świętej heleny ['korsyka']
# WA:  wyrażenie idiomatyczne ['idiom']
# WA:  the imaginary invalid ['„chory z urojenia”']
# WA:  baktrian ma dwa garby ['dwa', '2']
# WA:  sierpień ['w sierpniu']
# WA:  nie ['niebieskiego']
# WA:  elipsa ma dwa ogniska ['dwie', '2']
# WA:  nie ['nów']
# WA:  5 ['dwie', '2']
# WA:  centralna ewidencja pojazdów dotyczy właścicieli pojazdów ['kierowców']
# WA:  we włoszech ['z włoch']
# WA:  nocny kochanek ['obywatel g.c.']
# WA:  serial "lalka" ['w „lalce”', '„lalka”']
# WA:  kalafonia jest otrzymywana z wosku pszczelego ['żywica']
# WA:  tak ['nie']
# WA:  fauna ['flory']
# WA:  „ab ovo” oznacza „od jajka” ['od jaja', 'od początku']
# WA:  powstanie listopadowe ['listopadowego']
# WA:  święty franciszek z asyżu ['św. franciszek']
# WA:  1778 ['w xviii', '18']
# WA:  kazimierz jagiellończyk ['kazimierz iv jagiellończyk']
# WA:  tak ['nie']
# WA:  tak ['nie']
# WA:  łokieć ['nadgarstek']
# WA:  ubijak ['makutra']
# WA:  spódnica dzwon ['krynolina']
# WA:  jan styka ['jan styka i wojciech kossak', 'wojciech kossak i jan styka']
# WA:  2015 ['w xxi', '21']
# WA:  samochody ['rowerem']
# WA:  lwów ['we lwowie']
# WA:  stajniarz ['koniuszy']
# WA:  stronnictwo czartoryskich ['familia']
# WA:  john m barry ['jalu kurek']
# WA:  męski ['damski']
# WA:  1915 ['w 1916']
# WA:  tatry ['z karkonoszami']
# WA:  1865 ['w xix', '19']
# WA:  złoty kij ['złoty samowar']
# WA:  włochy ['do włoch']
# WA:  władysław łokietek był poprzednim królem polski dla kazimierza wielkiego ['ojcem', 'ojciec']
# WA:  w krakowie ['mysłowic']
# WA:  jednostką paskala jest pa (paskal) ['ciśnienia']
# WA:  carrom ['w dominie', 'domino']
# WA:  zakon benedyktynów ['benedyktynów']
# WA:  część iii ['z drugiej', '2']
# WA:  1096 ['w xi', '11']
# WA:  skała magmowa ['magmowa']
# WA:  oskarżyciel publiczny ['prokurator']
# WA:  ramoneska to rodzaj kurtki ['rodzaj kurtki']
# WA:  52 ['w xvi', '16']
# WA:  7 ['piętnaście', '15']
# WA:  tkanka przewodząca ['łyko']
# WA:  epoka kamienia była starsza ['kamienia']
# WA:  three of us ['kasia kowalska']
# WA:  dayton ['w dęblinie']
# WA:  za prezydentury stanisława wojciechowskiego ['stanisława wojciechowskiego']
# WA:  strojem męskim ['kobiecego']
# WA:  7 ['w xix', '19']
# WA:  77 ['w xvi', '16']
# WA:  stent to rodzaj implantu wewnątrznaczyniowego ['implant wewnątrznaczyniowy']
# WA:  john fitzgerald kennedy zginął w dallas ['w dallas']
# WA:  programem telewizyjnym autorstwa jerzego wasowskiego i jeremiego przybory był "kabaret starszych panów" ['„kabaret starszych panów”']
# WA:  imię lub nazwę podmiotu w zdaniu ['kto? co?']
# WA:  1898 ['w xix', '19']
# WA:  tak ['nie']
# WA:  maria ['weronika']
# WA:  sake wytwarza się z ryżu ['z ryżu']
# WA:  7 ['jeden', '1']
# WA:  "lord of the flies" ['„władca much”']
# WA:  francuski ['francuskojęzycznego']
# WA:  „homo faber” oznacza „człowiek jako twórca” ['człowiek twórca']
# WA:  nowa zelandia i australia ['od nowej zelandii']
# WA:  nie ['niemcy']
# WA:  kościół prawosławny ['prawosławny']
# WA:  jan olszewski ['jarosław kaczyński']
# WA:  47 ['w xix', '19']
# WA:  890 ['8,90 m']
# WA:  0 ['zero']
# WA:  2 ['nie ma rąk', 'nic']
# WA:  złodzieja można złapać na gorącym uczynku ['na gorącym']
# WA:  george stephenson ['richard trevithick']
# WA:  maria kownacka ['jan miodek']
# WA:  jd salinger ['juliusz verne', 'verne']
# WA:  [imię i nazwisko] jest szefem wydziału [nazwa wydziału] ['dziekan']
# WA:  bitwę pod trafalgarem wygrała brytyjska flota pod dowództwem admirała horatio nelsona ['brytyjczycy', 'anglicy']
# WA:  król teb kreon ['kreon']
# WA:  tak ['nie']
# WA:  rudy żelaza ['ruda']
# WA:  zbrojmistrz ['rusznikarz']
# WA:  jeździectwo ['boks']
# WA:  a ['trójkąt']
# WA:  leszek balcerowicz ['hanna gronkiewicz-waltz']
# WA:  1226 ['w xiii', '13']
# WA:  większość krajów na świecie wymienia jako te ['prawą', 'prawą stroną jezdni']
# WA:  warna leży nad morzem czarnym ['nad morzem czarnym', 'czarnym']
# WA:  międzynarodowa organizacja pomocy ekonomicznej (mope) ['united nations relief and rehabilitation administration', 'unrra']
# WA:  1952 ['w 1970']
# WA:  jednoroczna ['bylina']
# WA:  123 ['dwóch lat', '2 lata']
# WA:  atramentem ['płynnym złotem']
# WA:  można uzyskać krótkoterminową pożyczkę pod zastaw posiadanych cennych przedmiotów lub papierów wartościowych w instytucjach finansowych ['w lombardzie']
# WA:  wybrzeże riwiery francuskiej ['lazurowe wybrzeże']
# WA:  salomon nie naleje wina ['z pustego']
# WA:  100 ['ten, który trwa 100 minut', '100 minut', '1']
# WA:  kasimir malevich ['witkacy', 'stanisław ignacy witkiewicz', 'witkiewicz']
# WA:  wieża myśliwska ['ambona']
# WA:  janusz kondratiuk ['juliusz machulski']
# WA:  xiv wiek ['w xiv', '14']
# WA:  nasycanie cieczy gazem ['saturacja']
# WA:  bakšiš ['bakszysz']
# WA:  5 ['około tysiąca', 'tysiąc']
# WA:  we włoszech ['włoch']
# WA:  1 ['książę wellington', 'arthur wellesley']
# WA:  kapitol ['kwirynał']
# WA:  tofu jest produkowane z soi ['z soi', 'soja']
# WA:  procentowa ['stopa']
# WA:  związki tlenu nazywane są tlenkami ['tlenki']
# WA:  21 ['21 lat']
# WA:  hormon luteinizujący ['prolaktyna', 'laktotropina']
# WA:  amper (a) ['amper']
# WA:  1981 ['ronald reagan']
# WA:  tak ['nie']
# WA:  gmina ['gromada']
# WA:  stukot ['hołubiec']
# WA:  mount everest ['annapurna']
# WA:  janusz korczak napisał trzy książki o królu maciusiu ['dwie', '2']
# WA:  romantyzm i pozytywizm ['romantyzmu']
# WA:  królestwo włoch ['we włoszech', 'włochy']
# WA:  philippe pétain ['ferdinand foch', 'foch']
# WA:  lira ['na lirze']
# WA:  prostopadłościan kwadratowy ['sześcian']
# WA:  order orła białego ['order virtuti militari']
# WA:  usa ['w danii']
# WA:  zakład piłowania ['tartak']
# WA:  pantofle ['ciżma']
# WA:  meduza jest wielokomórkowym zwierzęciem ['wielokomórkowym']
# WA:  masa rogowa ['szylkret']
# WA:  pszenica ['ryż']
# WA:  roman dmowski ['adam koc', 'koc']
# WA:  amazonki okaleczały swoje ramiona ['odcinały prawą pierś']
# WA:  babia góra ['turbacz']
# WA:  rzut oszczepem ['w pchnięciu kulą']
# WA:  na skrzypcach ['na cymbałach']
# WA:  łacina ['po łacinie']
# WA:  atena ['parys']
# WA:  nie ['tak']
# WA:  andrzej bobola ['babinicz']
# WA:  nie ['tak']
# WA:  gwinei ['z francji']
# WA:  šatna ['pawlacz']
# WA:  phalanx ['falanga']
# WA:  język esperanto ['esperanto']
# WA:  ziemia okrąża słońce raz w ciągu roku ['raz', 'jeden raz']
# WA:  piszczałka ['suwak']
# WA:  jezioro ren ['przez jezioro bodeńskie']
# WA:  stoper służy do pomiaru czasu ['do pomiaru czasu', 'czasu']
# WA:  stanisław wyspiański ['heleny modrzejewskiej']
# WA:  tak ['nie']
# WA:  xviii wiek ['w xviii', '18']
# WA:  jedność czasu ['akcji']
# WA:  japonia ['w usa', 'w stanach zjednoczonych']
# WA:  pruska ['prus']
# WA:  szczęśliwego nowego jorku ['„kingsajz”']
# WA:  powiedzenie oznacza „leczyć siebie samego” ['lekarzu, lecz się sam']
# WA:  bałwan i morska breja ['bałwan']
# WA:  8 ['discovery']
# WA:  dynastia stuartów ['ze stuartów']
# WA:  knickerbockers ['pumpy']
# WA:  król kroisos z lidy ['gajusz juliusz cezar']
# WA:  ludwik ['ludwik solski', 'solski']
# WA:  larwy motyli nazywane są gąsienicami ['gąsienice']
# WA:  aleksander sołżenicyn ['doktor żywago']
# WA:  4 ['jeden', '1']
# WA:  1928 ['w 1929']
# WA:  posągi kamienne kobiet zwane są kamieniami kurhanowymi ['baby kamienne']
# WA:  powstania styczniowego ['tadeusza kościuszki', 'kościuszki']
# WA:  johannes gutenberg ['gutenberg']
# WA:  chaika ['czajki']
# WA:  matthew dunn ['wiktor suworow']
# WA:  maria ['monika']
# WA:  „pierwszy dzień” ['„pamiętnik starego subiekta”']
# WA:  dwadzieścia części (pieśni ['z dwudziestu czterech', '24']
# WA:  warszawski festiwal jazzowy ['jazz jamboree']
# WA:  afryka wschodnia ['z afryki']
# WA:  zakon paulinów ['paulini']
# WA:  - ['beta-karoten']
# WA:  srebro pływa w rtęci ['pływa']
# WA:  2 ['dwadzieścia', '20']
# WA:  polisemia ['pleonazm']
# WA:  100 ['michael h. hart', 'hart']
# WA:  makowiec ['z maku', 'mak']
# WA:  polska ['w polsce']
# WA:  maksymilian robespierre był prawnikiem ['prawnikiem']
# WA:  w krakowie ['we wrocławiu']
# WA:  2 ['o']
# WA:  jan iii sobieski ['zygmunt iii waza']
# WA:  stany zjednoczone ameryki ['usa', 'stanów zjednoczonych']
# WA:  uniwersytet wileński powstał wcześniej ['uniwersytet wileński', 'wileński']
# WA:  nie ['do chin']
# WA:  monitor ['monitor komputerowy']
# WA:  andantino jest wolniejsze od andante ['szybsze']
# WA:  willy ['gucio']
# WA:  brooklyn ['bronx']
# WA:  basia trzetrzelewska ['beata kozidrak']
# WA:  „czterej jeźdźcy apokalipsy” ['rudy 102', '„rudy”']
# WA:  syn ['bratem zeusa', 'bratem']
# WA:  1390 ['w xv', '15']
# WA:  donald tusk ['jacek kuroń']
# WA:  wielbłąd dwugarbny ['baktrian']
# WA:  przedstawiciel pierwotnej ludności kraju określa się jako autochton ['autochton']
# WA:  modulator kodowania impulsów cyfrowych (ang coded pulse modulator) ['modem']
# WA:  kłosówka ['kutia']
# WA:  antonio vivaldi ['vivaldi']
# WA:  olimp ['na górze olimp', 'na olimpie']
# WA:  narządu wzroku ['oczu', 'oka']
# WA:  bambus jest drzewem ['trawą']
# WA:  sulejman wspaniały ['sulejman']
# WA:  głowa i twarz ['twarz', 'głowę']
# WA:  ruch palikota ['samoobrona']
# WA:  jastrzębiec ['wczele']
# WA:  skok w dal ['w pchnięciu kulą']
# WA:  świątynia nazywała się panteon ['panteon']
# WA:  maciej kurzajewski ['kazimierz kaczor', 'kaczor']
# WA:  tak ['nie']
# WA:  „taniec zmysłów” ['„wirujący seks”']
# WA:  ernest hemingway ['irwina shawa', 'shawa']
# WA:  grafit ['diament']
# WA:  prędkość wiatru ['przyspieszenie']
# WA:  era paleozoiczna ['paleozoik']
# WA:  "lament podolskiego" ['pieśń o spustoszeniu podola przez tatarów']
# WA:  nie ['kiełbasa']
# WA:  sołtys jest mianowany przez wójta ['wybierany przez mieszkańców']
# WA:  hannibal barca ['hannibal']
# WA:  nie ['tak']
# WA:  jak wrony ['i one']
# WA:  pszenica ['z jęczmienia']
# WA:  łącznik ['spójnik']
# WA:  bonapartowie ['burboni']
# WA:  tak ['tylko w liczbie mnogiej']
# WA:  1099 ['w xi', '11']
# WA:  50 ['stany']
# WA:  brat jana kochanowskiego ['bratem']
# WA:  łaba ['warta']
# WA:  11 ['jeden', '1']
# WA:  stade roland garros w paryżu ['w paryżu']
# WA:  16 ['w xix', '19']
# WA:  ptaki ['owiec']
# WA:  gżegżółka to zwyczajowa nazwa dla ptaka zwanego sikorką zielonką ['kukułki']
# WA:  - ['lany poniedziałek']
# WA:  julian tuwim ['ksiądz jan twardowski', 'twardowski']
# WA:  xii wiek ['w xii', '12']
# WA:  ciśnienie atmosferyczne ['ciśnienie']
# WA:  warszawa ['w paryżu']
# WA:  3 ['z dwóch', 'z dwu', '2']
# WA:  stopień ['rumb']
# WA:  muzeum pergamońskim w berlinie ['w luwrze', 'luwr']
# WA:  szabat jest obchodzony co tydzień ['co tydzień', 'co sobotę', 'w każdą sobotę']
# WA:  fizyka ['matematyką']
# WA:  alpha ursae minoris ['gwiazda polarna']
# WA:  krzyż orderu odrodzenia polski ma cztery ramiona ['cztery', '4']
# WA:  50 ['dwa', '2']
# WA:  150 ['w xix', '19']
# WA:  cała nuta składa się z czterech szesnastek ['z szesnastu', '16']
# WA:  likwidacja ['ludobójstwo']
# WA:  pułapka ['szklana']
# WA:  wszystkie państwa ue ['we włoszech', 'włochy']
# WA:  tory ['talmud']
# WA:  legiony polskie ['legiony']
# WA:  augustus waters ['gladiatorzy']
# WA:  milimetr ['promil']
# WA:  janusz christa ['szklarski']
# WA:  wierzący wykonuje rachunek katolicki ['rachunek sumienia', 'sumienia']
# WA:  juliusz słowacki ['adama mickiewicza']
# WA:  krupp ag ['friedrich krupp ag', 'krupp']
# WA:  ocean zachodnioindyjski ['pacyfik']
# WA:  "jeden za wszystkich ['jeden za wszystkich, wszyscy za jednego']
# WA:  park grochowski w warszawie ['pod parkanami']
# WA:  afganistan ['na terenie pakistanu']
# WA:  janusz pająk ['józef chychła']
# WA:  tak ['nie']
# WA:  „dies irae” oznacza „dzień gniewu” ['dzień gniewu']
# WA:  justyna ['„dziewczyna szamana”']
# WA:  teatr la scala ['la scala']
# WA:  eurysteus ['augiasz']
# WA:  jednostką w żegludze jest kabel ['odległości']
# WA:  jan styka ['marcello bacciarelli', 'bacciarelli']
# WA:  tak ['z wiśni']
# WA:  zwrotnik raka ['równik']
# WA:  tak ['nie']
# WA:  lodowcowy materiał skalny ['morena']
# WA:  - ['tobogan']
# WA:  tak ['nie']
# WA:  kazimierz odnowiciel żył wcześniej ['kazimierz odnowiciel']
# WA:  adam michnik ['nikt']
# WA:  konferencja potsdamska ['jałtańskiej', 'na konferencji jałtańskiej', 'w jałcie']
# WA:  mieszkaniec szczawnicy to małopolanin ['szczawniczanin']
# WA:  arystokratyczne rządy autorytarne ['oligarchia']
# WA:  dynastia wettinów ['wettynów']
# WA:  80 ['więcej niż 80 lat', 'więcej']
# WA:  opłata wynosiła jedną srebrną monetę ['jeden obol', '1 obol']
# WA:  neptuna ['papieża']
# WA:  wiskozymetr służy do pomiaru lepkości płynów ['lepkości']
# WA:  alaska ['hawaje']
# WA:  latająca odznaka ['baretka']
# WA:  ziemniak ma więcej kalorii ['ziemniak']
# WA:  wielki wóz ['wielkiej niedźwiedzicy']
# WA:  cylinder ['szapoklak']
# WA:  kapitol w waszyngtonie jest własnością stanów zjednoczonych ['kongresu stanów zjednoczonych', 'kongresu usa']
# WA:  św łukasz był lekarzem ['lekarzem']
# WA:  trawa ['na trawiastej']
# WA:  osoby poruszające się per pedes poruszają się pieszo ['pieszo']
# WA:  sayyid ['szejk']
# WA:  ekskomunikacja ['eksmisja']
# WA:  bronisław piłsudski był bratem józefa piłsudskiego ['bratem']
# WA:  wojska francuskie ['szwoleżerowie']
# WA:  mms ['mms-em']
# WA:  dwie osoby ['dwóch', '2']
# WA:  cmentarz powązkowski i cmentarz rakowicki ['na cmentarzu łyczakowskim', 'na łyczakowskim']
# WA:  panama ['w chinach']
# WA:  sodu ['sód']
# WA:  "król lear" ['„dziady”']
# WA:  dwóch papieży nosiło oba imiona jan i paweł ['dwóch', '2']
# WA:  bitwy nad marną miały miejsce podczas i i ii wojny światowej ['podczas i wojny światowej', '1']
# WA:  węzeł świetlny ['lorenc']
# WA:  rosja ['do rosji']
# WA:  - ['sam autor', 'antoine de saint-exupéry']
# WA:  tony stark to bohater przemieniający się w iron mana ['w iron mana']
# WA:  jastrzębiec ['tępa podkowa']
# WA:  "aurora" ['z „aurory”']
# WA:  pismo „polityka” jest wydawane tygodniowo ['co tydzień', 'tygodnik']
# WA:  rzeka jangcy ['jangcy']
# WA:  stuntman ['kaskader']
# WA:  biały ['zielony']
# WA:  trapez ma cztery boki ['cztery', '4']
# WA:  jerzy stuhr ['kazimierz']
# WA:  kwas solny ['azotowy']
# WA:  dynastia grimaldi ['z grimaldich']
# WA:  116 ['nigdy', 'wcale', 'zero', '0']
# WA:  dzwonki rowerowe ['janczary']
# WA:  janusz lewandowski ['tadeusz syryjczyk']
# WA:  łeba ['chałupy']
# WA:  - ['w auschwitz']
# WA:  82 ['sześćdziesiąt dwa', '62']
# WA:  legia warszawa ['wisła kraków']
# WA:  1783 ['w xviii', '18']
# WA:  królewski najazd szwedzki ['potop szwedzki']
# WA:  "omega" ['mazurek']
# WA:  anion posiada przewagę elektronów ['elektronów']

# %% [markdown]
# ## Finetuning

# %%
training_data = []
for i in range(len(questions)):
    training_data.append({"prompt" : f"<{questions[i]}>", "completion": f"<{answers[i][0]}>"})
sampled_data = np.random.choice(training_data, 500)
