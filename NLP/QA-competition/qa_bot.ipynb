# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Explore questions and answers

# %%
questions, answers = [], []
with open('data/task2_questions_with_answers.tsv', encoding="UTF-8") as f:
    for line in f.readlines():
        try:
            q, *a = line.strip().split('\t')
            questions.append(q)
            answers.append(a)
        except Exception as e:
            print(line)

# %%
def longest_answer():
    for ans in answers:
        for a in ans:
# Out:
# [['alfa'],
#  ['cięciwa'],
#  ['w Egipcie'],
#  ['tak'],
#  ['Mazowsze'],
#  ['w Indiach'],
#  ['102'],
#  ['Kanał Sueski'],
#  ['tak'],
#  ['czterech', 'czworo', '4'],
#  ['szewcy'],
#  ['becquerel'],
#  ['Stanów Zjednoczonych', 'USA'],
#  ['melonik'],
#  ['menisk'],
#  ['Aleksander Graham Bell'],
#  ['mopanku'],
#  ['azotu'],
#  ['tak'],
#  ['tabakiera dla nosa'],
#  ['punkt zero'],
#  ['Paul Gauguin'],
#  ['Raul'],
#  ['sojusznik'],
#  ['Raka'],
#  ['Montmartre'],
#  ['hipoteza'],
#  ['dokąd idziesz'],
#  ['Pan Twardowski'],
#  ['cykuta'],
#  ['Hawana'],
#  ['James Bond'],
#  ['gotyckim'],
#  ['w XIV', '14'],
#  ['w Paryżu'],
#  ['tak'],
#  ['Roman Kłosowski'],
#  ['w Europie'],
#  ['Katarzyna Cichopek'],
#  ['w Tatrach'],
#  ['dziewiąte'],
#  ['na Honsiu'],
#  ['Główny Urząd Statystyczny'],
#  ['do Grecji'],
#  ['tak'],
#  ['fajka'],
#  ['„Krótki film o miłości”'],
#  ['pożyczaj'],
#  ['beczkę'],
#  ['Kraków'],
#  ['w Fatimie'],
#  ['szybko'],
#  ['nie'],
#  ['nad Niemnem', 'Niemen'],
#  ['Kreol'],
#  ['dwutlenku węgla', 'CO2'],
#  ['rządy tłumu'],
#  ['w Londynie'],
#  ['Sokratesa'],
#  ['nie'],
#  ['trójkątny'],
#  ['tak'],
#  ['w 1943'],
#  ['360'],
#  ['bitwa pod Borodino'],
#  ['w Sydney'],
#  ['Francja'],
#  ['w tenisie', 'w tenisie ziemnym'],
#  ['Helena Marusarzówna'],
#  ['niższy'],
#  ['Piotr'],
#  ['w Afryce'],
#  ['w XIII', '13'],
#  ['Wazów'],
#  ['z Azji'],
#  ['w Kanadzie'],
#  ['Hermes'],
#  ['jarmułka', 'kipa', 'sztrajmł', 'sztrajmel', 'sztrejmł'],
#  ['prezydent'],
#  ['pod Lipskiem'],
#  ['w Wielkiej Brytanii'],
#  ['Zemsta nietoperza'],
#  ['nad Wisłą'],
#  ['Radziejowa'],
#  ['sprytny'],
#  ['koryfeusz'],
#  ['dywizjon', 'pułk lotniczy'],
#  ['w 1949'],
#  ['piwo'],
#  ['w piątek'],
#  ['Halloween'],
#  ['w XIX', '19'],
#  ['kijanki'],
#  ['w boksie'],
#  ['Ludwika XIII'],
#  ['z brązu'],
#  ['Błyskawica'],
#  ['Julian Tuwim'],
#  ['David Livingstone'],
#  ['w maju'],
#  ['katoda'],
#  ['tak'],
#  ['Norwida'],
#  ['Bolesław Krzywousty'],
#  ['Soplicowo'],
#  ['owcy'],
#  ['hrabia'],
#  ['kapelusz'],
#  ['Hades'],
#  ['Wołodymyr Zełenski'],
#  ['w Stanach Zjednoczonych', 'w USA'],
#  ['Lancelot'],
#  ['w Kabarecie Olgi Lipińskiej'],
#  ['do Tadeusza'],
#  ['Kto śpiewa piosenkę z czołówki M jak miłość?'],
#  ['Marek Kondrat'],
#  ['na Oceanie Spokojnym', 'na Pacyfiku'],
#  ['Nautilus'],
#  ['„Przedwiośnia”'],
#  ['Artur Grottger'],
#  ['z Polski'],
#  ['z XII', '12'],
#  ['katarakta'],
#  ['Jan III Sobieski'],
#  ['Trybunał Stanu'],
#  ['własnoręcznie'],
#  ['jednorożec'],
#  ['Ryszarda Wagnera'],
#  ['Canaletto'],
#  ['Anawa'],
#  ['na Bergamutach'],
#  ['Jean Foucault'],
#  ['Sudan'],
#  ['tak'],
#  ['Ateny Partenos'],
#  ['tak'],
#  ['nie mają skrzydeł', 'zero', '0'],
#  ['w XIX', '19'],
#  ['żonkil'],
#  ['Tomasz'],
#  ['z Kariotu'],
#  ['o kradzież obrazu'],
#  ['kalendy'],
#  ['w 1964'],
#  ['pieta'],
#  ['Orson Welles'],
#  ['„Dama z łasiczką”'],
#  ['zbiór starożytnych rzeźb greckich'],
#  ['w Oslo'],
#  ['Marcin Luter'],
#  ['byk'],
#  ['nie'],
#  ['kasztel'],
#  ['z XIX', '19'],
#  ['Janina Ochojska'],
#  ['Sejm'],
#  ['w Chinach'],
#  ['Jan III Sobieski'],
#  ['w mennicy'],
#  ['SARP'],
#  ['Arnold Schwarzenegger'],
#  ['barszcz'],
#  ['w Malborku'],
#  ['trzynastozgłoskowcem', '13'],
#  ['literatury'],
#  ['kiełbie'],
#  ['młode wilki'],
#  ['z Bajkonuru'],
#  ['nie'],
#  ['pawia'],
#  ['tak'],
#  ['Bullerbyn'],
#  ['w Paryżu'],
#  ['z dębów'],
#  ['chrząszcz'],
#  ['Mirosław'],
#  ['tak'],
#  ['polio'],
#  ['nie'],
#  ['majora'],
#  ['rtęci'],
#  ['zęby mądrości'],
#  ['Karkonosze'],
#  ['wodery'],
#  ['w Babilonie'],
#  ['Pan Wołodyjowski'],
#  ['Sejm'],
#  ['franciszkanie'],
#  ['Kazimierz Wielki'],
#  ['kanclerz'],
#  ['litera O'],
#  ['giermek'],
#  ['tak'],
#  ['jest Brazylijczykiem'],
#  ['Rubik'],
#  ['tak'],
#  ['złotego deszczu'],
#  ['nie'],
#  ['w Czechach'],
#  ['w 1944'],
#  ['Admiralicja'],
#  ['oscypek'],
#  ['defetyzm'],
#  ['Kazimierz Wielki'],
#  ['siedem', '7'],
#  ['Oceanu Atlantyckiego', 'Atlantyku'],
#  ['w Ameryce Północnej'],
#  ['od XX'],
#  ['ze Szwecji'],
#  ['Michelin'],
#  ['w Afryce'],
#  ['nie'],
#  ['koniec języka'],
#  ['prozą'],
#  ['baca'],
#  ['związek chemiczny'],
#  ['Sekwany'],
#  ['w listopadowym'],
#  ['nie'],
#  ['1927'],
#  ['tak'],
#  ['gruźlicę'],
#  ['w Chinach'],
#  ['pod Grunwaldem'],
#  ['fenek'],
#  ['Spodek'],
#  ['polskiego'],
#  ['Anubis'],
#  ['Sumerowie'],
#  ['futryna'],
#  ['króla', 'monarchy', 'króla Jana bez Ziemi'],
#  ['uzurpator'],
#  ['Cullinan', 'Wielka Gwiazda Afryki'],
#  ['fosforytów'],
#  ['Stefan Żeromski'],
#  ['mikrobiologia'],
#  ['„La Dolce Vita”', '„Słodkie życie”'],
#  ['tak'],
#  ['tak'],
#  ['niedźwiedź'],
#  ['w Powstaniu Kościuszkowskim'],
#  ['siarka'],
#  ['motylkowate', 'bobowate'],
#  ['Wielka Karta Swobód'],
#  ['Fatalista'],
#  ['w Szczebrzeszynie'],
#  ['na Krecie'],
#  ['liczby przeciwne'],
#  ['panie ministrze'],
#  ['pacynka'],
#  ['Montmartre'],
#  ['w Nowym Jorku'],
#  ['gestapo'],
#  ['i ty, Brutusie, przeciw mnie'],
#  ['Michael'],
#  ['Berlin'],
#  ['Rzeszów'],
#  ['dyktando'],
#  ['dementi'],
#  ['solfeż'],
#  ['Walt Disney'],
#  ['Okopy Św. Trójcy'],
#  ['pieriestrojka'],
#  ['Półwysep Arabski', 'Arabski'],
#  ['płoty'],
#  ['habemus papam'],
#  ['brzuchu'],
#  ['Ania'],
#  ['nie'],
#  ['w Warszawie'],
#  ['tak'],
#  ['nocą'],
#  ['Arkadia'],
#  ['Aleksandra Macedońskiego'],
#  ['na Oceanie Atlantyckim', 'na Atlantyku'],
#  ['tak'],
#  ['w Gdańsku'],
#  ['Margaret Thatcher'],
#  ['Europejskie Stowarzyszenie Wolnego Handlu'],
#  ['w 1945'],
#  ['do Rolanda'],
#  ['Jankiel'],
#  ['Figaro'],
#  ['w Niemczech'],
#  ['jeden', '1'],
#  ['cysterna'],
#  ['trolejbus'],
#  ['deklinacja magnetyczna'],
#  ['H2O'],
#  ['Tbilisi'],
#  ['John Cleese'],
#  ['admirał floty'],
#  ['w Krakowie'],
#  ['co 500 lat'],
#  ['przeciwko gruźlicy'],
#  ['z Anglii'],
#  ['stetoskop'],
#  ['nie'],
#  ['przypuszczający'],
#  ['Konferencja Bezpieczeństwa i Współpracy w Europie'],
#  ['Iwan IV Groźny'],
#  ['w Rumunii'],
#  ['„Śluby panieńskie”'],
#  ['Koran'],
#  ['Stefana Chmieleckiego'],
#  ['w Niemczech'],
#  ['sadysta'],
#  ['Adolfa Hitlera'],
#  ['dodatni'],
#  ['Kanał św. Jerzego'],
#  ['Nostromo'],
#  ['na białym'],
#  ['odsiecz', 'wsparcie'],
#  ['do Morza Czarnego'],
#  ['keratyna'],
#  ['żoną'],
#  ['ciura', 'luzak'],
#  ['w Ameryce Północnej'],
#  ['na Marsie'],
#  ['6 niedziel'],
#  ['Steven Spielberg'],
#  ['ferm'],
#  ['szarpany'],
#  ['E.T.'],
#  ['w Polsce'],
#  ['w XIX', '19'],
#  ['jedna', '1'],
#  ['tryptyk'],
#  ['Armia Krajowa'],
#  ['jasyr'],
#  ['blotka'],
#  ['„Millenium”'],
#  ['w 1979'],
#  ['trzy', '3'],
#  ['do Nowego Jorku'],
#  ['sto', '100'],
#  ['pejsy'],
#  ['w „Misiu”'],
#  ['w XIX', '19'],
#  ['w 1989'],
#  ['Elita'],
#  ['Jadwiga'],
#  ['podkowa'],
#  ['nie'],
#  ['Karenina'],
#  ['Neron'],
#  ['nuncjatura'],
#  ['żółte'],
#  ['w Berlinie'],
#  ['Order Orła Białego'],
#  ['prawidłowy', 'foremny'],
#  ['do Meksyku'],
#  ['przerzutka'],
#  ['Oliwa'],
#  ['Jan bez Ziemi'],
#  ['w XIX', '19'],
#  ['nie'],
#  ['nabiał'],
#  ['nie'],
#  ['Apolla', 'Apollina'],
#  ['Karol Linneusz'],
#  ['Gustaw Aleksander'],
#  ['w 1969'],
#  ['trzy', '3'],
#  ['Władysław Reymont'],
#  ['Lidka'],
#  ['w średniowieczu'],
#  ['w XVI', '16'],
#  ['w hucie'],
#  ['szisza'],
#  ['Tęcza'],
#  ['Piotr Wielki'],
#  ['Tradycja'],
#  ['Rudolf Diesel'],
#  ['przed ślubem'],
#  ['tak'],
#  ['w 1957'],
#  ['Stanisława Hadyny'],
#  ['Akcja Wisła'],
#  ['z Francji'],
#  ['Izaak'],
#  ['Piotr Czajkowski'],
#  ['do'],
#  ['palna', 'Londyn'],
#  ['faul'],
#  ['PEN club'],
#  ['w Wiedniu'],
#  ['Igor'],
#  ['dwa', '2'],
#  ['w „Hamlecie”'],
#  ['tak'],
#  ['tak'],
#  ['Ignacy Krasicki'],
#  ['tak'],
#  ['XV', '15'],
#  ['w Szwecji'],
#  ['Narodowy Fundusz Zdrowia'],
#  ['stadnina'],
#  ['NN'],
#  ['tak'],
#  ['do Wielkiej Brytanii'],
#  ['Tadeusz'],
#  ['z Litwą'],
#  ['astygmatyzm'],
#  ['Persefona', 'Kora'],
#  ['wilkołak'],
#  ['Asyrii'],
#  ['serwis'],
#  ['Stanisław'],
#  ['w gotyckim'],
#  ['jedną', '1'],
#  ['Lew Tołstoj'],
#  ['Mikołaj Rej'],
#  ['-1'],
#  ['Bytomia'],
#  ['brutto'],
#  ['dwoje', '2'],
#  ['Czesław Tański'],
#  ['szeregowy', 'szeregowiec'],
#  ['w dioptriach'],
#  ['The Jackson 5'],
#  ['tak'],
#  ['pi'],
#  ['kopiejka'],
#  ['węża'],
#  ['pytanie retoryczne'],
#  ['binokle'],
#  ['„Rejs”'],
#  ['29 listopada 1830'],
#  ['nad Morzem Śródziemnym'],
#  ['w Grenadzie'],
#  ['na Powązkach', 'na Cmentarzu Powązkowskim'],
#  ['kalumet'],
#  ['Rodos'],
#  ['trzy', '3'],
#  ['babka'],
#  ['„Pan Tadeusz”'],
#  ['w XIX', '19'],
#  ['nie'],
#  ['Urszula'],
#  ['José'],
#  ['tak'],
#  ['Lipień', 'Lipieniowie'],
#  ['w Powstaniu Styczniowym'],
#  ['nirwana'],
#  ['ojca męża'],
#  ['60'],
#  ['Włoch'],
#  ['woda'],
#  ['hippika'],
#  ['klaser'],
#  ['dwie', '2'],
#  ['gazda'],
#  ['hiszpański'],
#  ['mimozami'],
#  ['Jan Sobieski'],
#  ['Dar Przemyśla'],
#  ['z jednym', '1'],
#  ['Zygmunt Stary'],
#  ['dusza zmarłego grzesznika wstępująca do ciała żywego'],
#  ['była neutralna'],
#  ['Piotrowi'],
#  ['w Asyżu'],
#  ['„Przedwiośnia”'],
#  ['tak'],
#  ['piłką nożną'],
#  ['2 miliony złotych'],
#  ['Marię Austriaczkę'],
#  ['bramkarza'],
#  ['The Rolling Stones'],
#  ['w Azji'],
#  ['w Łodzi'],
#  ['nie'],
#  ['Merkury'],
#  ['film'],
#  ['Wielką Brytanią'],
#  ['w Stanach Zjednoczonych', 'w USA'],
#  ['Roald Amundsen'],
#  ['uczciwa gra', 'gra zgodnie z zasadami'],
#  ['tak'],
#  ['zakaz Pauliego'],
#  ['Japonia'],
#  ['Bukareszt'],
#  ['nie'],
#  ['na Bałtyckim'],
#  ['z Hiszpanii'],
#  ['w 1901'],
#  ['mrówkami'],
#  ['tak'],
#  ['od miecza'],
#  ['glejt', 'list żelazny'],
#  ['w XVII', '17'],
#  ['nad Krakowem'],
#  ['Lara Croft'],
#  ['Francji'],
#  ['Kościuszko'],
#  ['Matka Boska'],
#  ['dzierżawcze'],
#  ['jedną', '1'],
#  ['Franklin Delano Roosevelt'],
#  ['Louis Braille'],
#  ['Karol IV Luksemburski'],
#  ['Henryk Dobrzański'],
#  ['Jan Brzechwa'],
#  ['ZSRR'],
#  ['Józefa Piłsudskiego'],
#  ['Zygmunta Freuda'],
#  ['Krwawa Maria', 'Bloody Mary'],
#  ['gilosz'],
#  ['w XX', '20'],
#  ['Kornel'],
#  ['Madonna'],
#  ['krater'],
#  ['w Atenach'],
#  ['Holandii'],
#  ['z Afryki'],
#  ['tak'],
#  ['Perfectu'],
#  ['trzech', '3'],
#  ['drapieżny'],
#  ['portugalski'],
#  ['magnezu'],
#  ['w Ameryce Południowej'],
#  ['Julian Tuwim'],
#  ['w Warszawie'],
#  ['prokurator'],
#  ['Marka Kotańskiego'],
#  ['chromu'],
#  ['w Bieszczadach'],
#  ['Jan Brzechwa'],
#  ['w Warszawie'],
#  ['Greenwich'],
#  ['broń'],
#  ['złote'],
#  ['był żeglarzem'],
#  ['Zakazane Miasto'],
#  ['Bułgarii'],
#  ['w czterech', '4'],
#  ['orzeł'],
#  ['placek'],
#  ['Węgier'],
#  ['Zgromadzenie Narodowe'],
#  ['szewc'],
#  ['George Washington', 'Jerzy Waszyngton'],
#  ['Jerzy Andrzejewski'],
#  ['w Egipcie'],
#  ['dwie', '2'],
#  ['gołębi'],
#  ['ochmistrz'],
#  ['tak'],
#  ['Julian Tuwim'],
#  ['w 1949'],
#  ['sypialnia'],
#  ['żadnej'],
#  ['w XIX', '19'],
#  ['Kraj Warty'],
#  ['Medea'],
#  ['Biała Przemsza'],
#  ['w wielkopolskim'],
#  ['Tennessee Williams'],
#  ['uszka'],
#  ['mniejsza'],
#  ['w Stanach Zjednoczonych', 'w USA'],
#  ['heraldyka'],
#  ['w Nowej Zelandii'],
#  ['hel'],
#  ['żaba'],
#  ['nie'],
#  ['nie'],
#  ['z Cypru'],
#  ['Theo'],
#  ['Jerzy II Rakoczy'],
#  ['John Glenn'],
#  ['Chorwacja'],
#  ['Mińsk'],
#  ['Jan Zamoyski'],
#  ['wręcz'],
#  ['Włodzimierz Wolski'],
#  ['franciszkanów'],
#  ['niby', 'jakby'],
#  ['w Argentynie'],
#  ['w Olimpii'],
#  ['z Portugalii'],
#  ['tak'],
#  ['serduszko'],
#  ['omega'],
#  ['Ernesto'],
#  ['„Nowy wspaniały świat”'],
#  ['na Litwie'],
#  ['dwie', '2'],
#  ['więcej'],
#  ['ćwiartka', 'ćwierć'],
#  ['Judi Dench'],
#  ['spółgłosek'],
#  ['Boreasz'],
#  ['w 1949'],
#  ['do Arabii Saudyjskiej'],
#  ['nad wiatrami'],
#  ['z Filistynów'],
#  ['mesa'],
#  ['akapit'],
#  ['malarię'],
#  ['trojka'],
#  ['piosenka'],
#  ['Walt Disney'],
#  ['Orfeusz'],
#  ['dwa', '2'],
#  ['tańcem'],
#  ['iglasta'],
#  ['Nowego Jorku'],
#  ['ogon'],
#  ['w 1000'],
#  ['dyptyk'],
#  ['włoskiej', 'włoski'],
#  ['atomowej'],
#  ['we francuskim'],
#  ['łania'],
#  ['nie'],
#  ['Wolfgang Amadeusz'],
#  ['Stefan'],
#  ['dżdżu'],
#  ['skala Mercallego'],
#  ['Krupówki'],
#  ['gołąb'],
#  ['biały'],
#  ['Toskania'],
#  ['Elektryczne Gitary'],
#  ['żubr'],
#  ['doping'],
#  ['zielone'],
#  ['na przykład'],
#  ['Tarzan'],
#  ['lont'],
#  ['Janusz Korczak', 'Stary Doktor', 'Pan Doktor'],
#  ['wypasaniem gęsi'],
#  ['kibuc'],
#  ['Kirkor'],
#  ['ani razu', '0'],
#  ['wilk'],
#  ['tak'],
#  ['z Efezu'],
#  ['wykonawcza'],
#  ['Obelix'],
#  ['do Włoch'],
#  ['w Michigan'],
#  ['tak'],
#  ['„Ostry dyżur”'],
#  ['z worka'],
#  ['po stronie Unii'],
#  ['Schleswig-Holstein'],
#  ['francuskim'],
#  ['Jan Matejko'],
#  ['Gustaw Herling-Grudziński'],
#  ['zwrotnik Koziorożca'],
#  ['Rumunia'],
#  ['Behemoth'],
#  ['dusicielem'],
#  ['Meksyk'],
#  ['koni', 'tylko koni'],
#  ['Jana Matejki'],
#  ['Hansa Klossa'],
#  ['garbarnia'],
#  ['Julian Ursyn'],
#  ['„W pogoni za rozumem”'],
#  ['nie'],
#  ['Wincenty'],
#  ['izbica', 'lodołam'],
#  ['Apeninów'],
#  ['Sorbona'],
#  ['Tower Bridge'],
#  ['Pegaz'],
#  ['do Cezara', 'do cesarza'],
#  ['Bajkonur'],
#  ['topora bojowego'],
#  ['szabat', 'szabas'],
#  ['tak'],
#  ['niebieski'],
#  ['Niccolò Machiavelli'],
#  ['nie'],
#  ['Sherlock Holmes'],
#  ['tak'],
#  ['Dejanira'],
#  ['Bazyliszek'],
#  ['hokej na lodzie'],
#  ['nie'],
#  ['w Lipsku'],
#  ['w XVIII', '18'],
#  ['ławice'],
#  ['w Londynie'],
#  ['Witold'],
#  ['Eugeniusz Bodo'],
#  ['batalista'],
#  ['„Człowiek z marmuru”'],
#  ['pochwalny'],
#  ['z Afryki'],
#  ['pałaca'],
#  ['Radom'],
#  ['sposób golenia głowy'],
#  ['kuponów'],
#  ['papiloty'],
#  ['Newy'],
#  ['od 1959'],
#  ['z trzema', '3'],
#  ['akupresura'],
#  ['Marianna'],
#  ['naturalizmu'],
#  ['Agata Christie'],
#  ['w Berlinie'],
#  ['metabolizm'],
#  ['runda'],
#  ['ze Śląska'],
#  ['na ramieniu'],
#  ['apostołowie'],
#  ['z „Zemsty”'],
#  ['Władysław Jagiełło'],
#  ['wielkie dzieło'],
#  ['w XIX', '19'],
#  ['Tadeusza Kościuszki'],
#  ['kołysanka'],
#  ['Yeti'],
#  ['w 1925'],
#  ['Anteusz'],
#  ['prolongata'],
#  ['spaghetti western'],
#  ['skautingu'],
#  ['serce'],
#  ['Marlon Brando'],
#  ['metan'],
#  ['lew'],
#  ['jedną', '1'],
#  ['także w jeziorach'],
#  ['pingwin cesarski'],
#  ['tak'],
#  ['został ścięty na gilotynie'],
#  ['decybel'],
#  ['lira'],
#  ['Elżbieta II', 'królowa brytyjska'],
#  ['spojrzeniem', 'wzrokiem'],
#  ['Oceanu Spokojnego', 'Pacyfiku'],
#  ['mrówki'],
#  ['fantastyka naukowa'],
#  ['zielony'],
#  ['z angielskiego'],
#  ['taraban'],
#  ['hula-hoop'],
#  ['Meduza'],
#  ['nie'],
#  ['z Jamajki'],
#  ['Ziemia'],
#  ['pretorianie'],
#  ['tak'],
#  ['nad Zatoką Perską'],
#  ['kot'],
#  ['Lajos'],
#  ['w kwietniu'],
#  ['południowy'],
#  ['tak'],
#  ['w Warszawie'],
#  ['roślina'],
#  ['Borowieckiego'],
#  ['w III', '3'],
#  ['Paryż'],
#  ['nie'],
#  ['w Katowicach'],
#  ['Stanisław Mikołajczyk'],
#  ['psów'],
#  ['fajki'],
#  ['Statua Wolności'],
#  ['Łajka'],
#  ['z orzeszków ziemnych'],
#  ['Rhett Butler'],
#  ['nie'],
#  ['Anubis'],
#  ['nie'],
#  ['Kalina'],
#  ['fiskus', 'fiscus'],
#  ['Angelina Jolie'],
#  ['Trafalgar Square'],
#  ['z igłą'],
#  ['Hypnos'],
#  ['sułtan'],
#  ['lisi krok'],
#  ['tak'],
#  ['tak'],
#  ['nie'],
#  ['„Ptaki ciernistych krzewów”'],
#  ['Pb'],
#  ['Posejdon'],
#  ['w XX', '20'],
#  ['Mikołaj Kopernik'],
#  ['dla syna'],
#  ['na malarię'],
#  ['salwa'],
#  ['tak'],
#  ['Har-Magedon', 'Armagedon'],
#  ['sekretarz stanu'],
#  ['w XV', '15'],
#  ['Przesłanie pana Cogito'],
#  ['Oceanu Atlantyckiego', 'Atlantyku'],
#  ['prymus'],
#  ['pozytywizm'],
#  ['pięć', '5'],
#  ['w Liverpoolu'],
#  ['mammologia'],
#  ['pozwalał pozostać niewidzialnym', 'zapewniał niewidzialność'],
#  ['w szkle'],
#  ['Nikifor Krynicki'],
#  ['Henryk Jaskuła'],
#  ['Albrecht Dürer'],
#  ['w Jerozolimie'],
#  ['Izraela'],
#  ['fresk'],
#  ['rubel'],
#  ['PGE Narodowy', 'Stadion Narodowy'],
#  ['Tekla'],
#  ['Willy Brandt'],
#  ['Kasprowy Wierch'],
#  ['w Chinach'],
#  ['w XIX', '19'],
#  ['Koziorożca'],
#  ['„Nocy i dni”'],
#  ['w 1950'],
#  ['niech żyje'],
#  ['Izabela'],
#  ['żałosny'],
#  ['Ramzes'],
#  ['w Łazienkach'],
#  ['„Następny do raju”'],
#  ['kuluary'],
#  ['tak'],
#  ['wotum nieufności'],
#  ['nie'],
#  ['genealogiczne'],
#  ['Hamlet'],
#  ['wiecha'],
#  ['ze Szwecji'],
#  ['mikst'],
#  ['harfa'],
#  ['Prus'],
#  ['w Oświęcimiu'],
#  ['cztery', '4'],
#  ['„Rejs”'],
#  ['izobaty'],
#  ['kolano'],
#  ['trampolina'],
#  ['Litwy'],
#  ['części zbroi'],
#  ['brama'],
#  ['rekin wielorybi'],
#  ['Isaac Newton'],
#  ['grafolog'],
#  ['Dzik'],
#  ['w Izraelu'],
#  ['do wiosłowania'],
#  ['tak'],
#  ['Kazimierz Wielki'],
#  ['duet'],
#  ['sos do sałatki', 'sos'],
#  ['Bug'],
#  ['kapelusz', 'melonik'],
#  ['Beata'],
#  ['piruet'],
#  ['Nepal'],
#  ['powód wypowiedzenia wojny'],
#  ['nurkuje'],
#  ['Oceanu Spokojnego', 'Pacyfiku'],
#  ['elementarz'],
#  ['okrąg'],
#  ['tak'],
#  ['trzy', '3'],
#  ['Piotra Wielkiego'],
#  ['w 1939'],
#  ['alba'],
#  ['Juliusz Słowacki'],
#  ['w 1917'],
#  ['kismet'],
#  ['matką'],
#  ['porywczy'],
#  ['planimetria'],
#  ['w 1991'],
#  ['pod Legnicą'],
#  ['majowy'],
#  ['w Afganistanie'],
#  ['z jabłkami'],
#  ['nie'],
#  ['Terpsychora'],
#  ['zielonego', 'bladego'],
#  ['szermierki'],
#  ['w Tatrach'],
#  ['kwadrat'],
#  ['z granitu'],
#  ['peklowanie'],
#  ['nie'],
#  ['ornat'],
#  ['tak'],
#  ['topik'],
#  ['w 1939'],
#  ['całkowanie'],
#  ['jezuitów'],
#  ['samurajowie'],
#  ['wikingowie'],
#  ['do Gogolina'],
#  ['łodzi podwodnej'],
#  ['Jadwiga'],
#  ['trunek'],
#  ['trzy', '3'],
#  ['ponieśli i wilka'],
#  ['cztery', '4'],
#  ['Wilhelm Conrad'],
#  ['Kasia Nosowska', 'Katarzyna Nosowska'],
#  ['nie'],
#  ['depilacja'],
#  ['koliber', 'hawańczyk'],
#  ['dziesiątego', '10'],
#  ['nie'],
#  ['„Przeminęło z wiatrem”'],
#  ['Mieszka I'],
#  ['za Stanisława Augusta Poniatowskiego'],
#  ['w XX', '20'],
#  ['Roza'],
#  ['panczeny'],
#  ['w Warszawie'],
#  ['lewostronny'],
#  ['piwa'],
#  ['Anny Stuart'],
#  ['Astrid Lindgren'],
#  ['wodnym'],
#  ['tak'],
#  ['fortepianu'],
#  ['romantyzmu'],
#  ['Cyceron'],
#  ['tanatofobia'],
#  ['w Warszawie'],
#  ['Black Sabbath'],
#  ['Ingmar Bergman'],
#  ['tak'],
#  ['lis'],
#  ['Sadełko'],
#  ['Polskie Towarzystwo Turystyczno-Krajoznawcze'],
#  ['ostra krawędź stoku górskiego'],
#  ['budżet państwa'],
#  ['na malowane'],
#  ['jednego'],
#  ['Adam Mickiewicz'],
#  ['As'],
#  ['w Stumilowym'],
#  ['baksztag'],
#  ['do RFN'],
#  ['oddawanie', 'Którym słowem określano damy dworskie?'],
#  ['Franciszek Karpiński'],
#  ['Korea'],
#  ['Szwajcaria'],
#  ['nie'],
#  ['asertywność'],
#  ['pod Ulm'],
#  ['John'],
#  ['z marcepana'],
#  ['21 dni'],
#  ['brunatny'],
#  ['w XVI', '16'],
#  ['najwyższe szczyty kontynentów'],
#  ['czarny'],
#  ['Labrador'],
#  ['tlen i krzem'],
#  ['w piłce nożnej'],
#  ['arachnologia'],
#  ['nie'],
#  ['Grecja'],
#  ['Galileusz'],
#  ['Atlantis'],
#  ['czterdzieści', '40'],
#  ['Gdańska'],
#  ['w „Janosiku”'],
#  ['Leonardo da Vinci'],
#  ['dymarki'],
#  ['tak'],
#  ['skrzypiec'],
#  ['żołd'],
#  ['waran'],
#  ['część budynku'],
#  ['Władysław Jagiełło'],
#  ['Jana Olbrachta'],
#  ['z „Konrada Wallenroda”'],
#  ['trzynaście', '13'],
#  ['kirkut'],
#  ['do Pacanowa'],
#  ['Stefan Żeromski'],
#  ['cztery', '4'],
#  ['break'],
#  ['Turkmenistanu'],
#  ['tynf'],
#  ['Wisła'],
#  ['Leningrad'],
#  ['Marlena Dietrich', 'Marlene Dietrich'],
#  ['historyczną'],
#  ['tak'],
#  ['ptasiego'],
#  ['napęd na cztery koła', 'napęd na 4 koła', 'four wheel drive'],
#  ['w warmińsko-mazurskim'],
#  ['tak'],
#  ...]
